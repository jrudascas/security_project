# %%
# importing required packages
import pandas as pd
import pandas_profiling
import numpy as np

# %%
data_path = '/home/jrudascas/Desktop/DelitosAltoImpacto_2017-2018.csv'

# %%
df = pd.read_csv(data_path, low_memory=False)
fielt_to_filter = 'CIRCUNSTANCIAS_PERSONA'
filtering = ['RIÑAS', 'RIÑA ENTRE COMPAÑEROS PERMANENTES', 'RIÑA ENTRE ESPOSOS', 'RIÑA ENTRE HERMANOS', 'RIÑA O CONFLICTO ENTRE PANDILLAS', 'RIÑA ENTRE HIJO-PADRE']
df = df[df[fielt_to_filter].isin(filtering)]

# %%
df.describe(include = 'all')
# Out:
#         ID_ORIGINAL TIPO_HECHO  \
# count       50494.0      50494
# unique          NaN          1
# top             NaN     DELITO
# freq            NaN      50494
# mean           -1.0        NaN
# std             0.0        NaN
# min            -1.0        NaN
# 25%            -1.0        NaN
# 50%            -1.0        NaN
# 75%            -1.0        NaN
# max            -1.0        NaN
#
#                                              TITULO_HECHO  \
# count                                               50494
# unique                                                  1
# top     1 DELITOS CONTRA LA VIDA Y LA INTEGRIDAD PERSONAL
# freq                                                50494
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# ...

# %%
df.head()
# Out:
#       ID_ORIGINAL TIPO_HECHO  \
# 145            -1     DELITO
# 149            -1     DELITO
# 1044           -1     DELITO
# 1049           -1     DELITO
# 2285           -1     DELITO
#
#                                            TITULO_HECHO                HECHO  \
# 145   1 DELITOS CONTRA LA VIDA Y LA INTEGRIDAD PERSONAL  LESIONES PERSONALES
# 149   1 DELITOS CONTRA LA VIDA Y LA INTEGRIDAD PERSONAL  LESIONES PERSONALES
# 1044  1 DELITOS CONTRA LA VIDA Y LA INTEGRIDAD PERSONAL  LESIONES PERSONALES
# 1049  1 DELITOS CONTRA LA VIDA Y LA INTEGRIDAD PERSONAL  LESIONES PERSONALES
# 2285  1 DELITOS CONTRA LA VIDA Y LA INTEGRIDAD PERSONAL  LESIONES PERSONALES
#
#       CUENTA_HECHOS                     CARACTERISTICA ARMA_EMPLEADA  \
# 145               1  RIÑA ENTRE COMPAÑEROS PERMANENTES  CONTUNDENTES
# 149               1  RIÑA ENTRE COMPAÑEROS PERMANENTES  CONTUNDENTES
# 1044              1                 RIÑA ENTRE ESPOSOS  CONTUNDENTES
# ...

# %%
pandas_profiling.ProfileReport(df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-c5473803fb1b> in <module>
# ----> 1 pandas_profiling.ProfileReport(df)
#
# ~/.virtualenvs/security/lib/python3.6/site-packages/pandas_profiling/__init__.py in __init__(self, df, **kwargs)
#      66
#      67         # Get dataset statistics
# ---> 68         description_set = describe_df(df)
#      69
#      70         # Get sample
#
# ~/.virtualenvs/security/lib/python3.6/site-packages/pandas_profiling/model/describe.py in describe(df)
#     538         with multiprocessing.pool.ThreadPool(pool_size) as executor:
#     539             series_description = {}
# --> 540             results = executor.starmap(multiprocess_1d, df.iteritems())
#     541             for col, description in results:
#     542                 series_description[col] = description
#
# ...
