# %% [markdown]
# # Análisis Exploratorio
#
#     Fuente de información: RNMC
#     Archivos: df_riñas_rnmc.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import calendar
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_columns', None)  
from wordcloud import WordCloud, STOPWORDS
import folium
from folium import plugins
import geopandas as gpd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-ef81de35c8cc> in <module>
#      12 import folium
#      13 from folium import plugins
# ---> 14 import geopandas as gpd
#
# ~/anaconda3/lib/python3.7/site-packages/geopandas/__init__.py in <module>
#       3 from geopandas.array import _points_from_xy as points_from_xy  # noqa
#       4
# ----> 5 from geopandas.io.file import read_file  # noqa
#       6 from geopandas.io.sql import read_postgis  # noqa
#       7 from geopandas.tools import sjoin  # noqa
#
# ~/anaconda3/lib/python3.7/site-packages/geopandas/io/file.py in <module>
#       4 import six
#       5
# ----> 6 import fiona
#       7
#       8 from geopandas import GeoDataFrame, GeoSeries
#
# ~/anaconda3/lib/python3.7/site-packages/fiona/__init__.py in <module>
#      81     os.environ["PATH"] = os.environ["PATH"] + ";" + libdir
#      82
# ---> 83 from fiona.collection import BytesCollection, Collection
#      84 from fiona.drvsupport import supported_drivers
#      85 from fiona.env import ensure_env_with_credentials, Env
#
# ~/anaconda3/lib/python3.7/site-packages/fiona/collection.py in <module>
#       7
#       8 from fiona import compat, vfs
# ----> 9 from fiona.ogrext import Iterator, ItemsIterator, KeysIterator
#      10 from fiona.ogrext import Session, WritingSession
#      11 from fiona.ogrext import buffer_to_virtual_file, remove_virtual_file, GEOMETRY_TYPES
#
# ImportError: libkea.so.1.4.7: cannot open shared object file: No such file or directory

# %% [markdown]
# # Load datasets

# %%
data_location = '/u01/user8/Documents/Riñas/RNMC/data_2019_11/df_riñas_rnmc.csv'
data = pd.read_csv(data_location,delimiter=",")
# Out:
# /u01/user8/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning:
#
# Columns (1,12,14) have mixed types. Specify dtype option on import or set low_memory=False.

# %% [markdown]
# # Basic dataset description

# %%
data.head()
# Out:
#           EXPEDIENTE      COMPARENDO       FECHA  HORA  ANIO  MES   LATITUD  \
# 0  11-001-6-2017-61   111056601       2017-01-30  0     2017  1    4.580549
# 1  11-001-6-2017-127  11001064701     2017-01-30  0     2017  1    4.596728
# 2  11-001-6-2017-146  11001040453     2017-01-30  0     2017  1    4.588841
# 3  11-001-6-2017-153  11001111037327  2017-01-30  0     2017  1    0.000000
# 4  11-001-6-2017-157  111064578       2017-01-30  0     2017  1    4.603355
#
#     LONGITUD  COD_LOCALIDAD NOMBRE_LOCALIDAD COD_UPZ        NOMBRE_UPZ  \
# 0 -74.142739  6              TUNJUELITO       UPZ42   VENECIA
# 1 -74.074857  17             CANDELARIA       UPZ94   LA CANDELARIA
# 2 -74.071710  3              SANTA FE         UPZ96   LOURDES
# 3  0.000000   8              KENNEDY          UPZ999  SIN LOCALIZACION
# 4 -74.081888  14             LOS MARTIRES     UPZ102  LA SABANA
#
#   COD_SCAT      NOMBRE_SECTOR_CAT COD_BARRIO          NOMBRE_BARRIO  \
# 0  002413   MUZU                   2950       VILLA XIMENA
# 1  003106   CENTRO ADMINISTRATIVO  186        CENTRO ADMINISTRATIVO
# 2  003212   LOURDES                3458       LOURDES
# 3  999999   SIN LOCALIZACION       999999999  SIN LOCALIZACION
# 4  004103   VOTO NACIONAL          2676       VOTO NACIONAL
#
#                               TIPO_SITIO  RANGO_EDAD_1    TITULO    CAPITULO  \
# 0  SITIOS PUBLICOS O ABIERTOS AL PUBLICO  30 - 34 A?OS  Titulo 3  Capitulo 1
# 1  SITIOS PUBLICOS O ABIERTOS AL PUBLICO  30 - 34 A?OS  Titulo 3  Capitulo 1
# 2  SITIOS PUBLICOS O ABIERTOS AL PUBLICO  25 - 29 A?OS  Titulo 3  Capitulo 1
# 3  SITIOS PUBLICOS O ABIERTOS AL PUBLICO  50 - 54 A?OS  Titulo 3  Capitulo 1
# 4  SITIOS PUBLICOS O ABIERTOS AL PUBLICO  30 - 34 A?OS  Titulo 3  Capitulo 1
#
#    ARTICULO  \
# 0  27
# 1  27
# 2  27
# 3  27
# 4  27
#
#                                                                                                                                                                                                                              DESCRIPCION_ARTICULO  \
# 0  Comportamientos que ponen en riesgo la vida e integridad. Corregido por el art. 1, Decreto 555 de 2017. Los siguientes comportamientos ponen en riesgo la vida e integridad de las personas, y, por lo tanto, son contrarios a la convivencia:
# 1  Comportamientos que ponen en riesgo la vida e integridad. Corregido por el art. 1, Decreto 555 de 2017. Los siguientes comportamientos ponen en riesgo la vida e integridad de las personas, y, por lo tanto, son contrarios a la convivencia:
# 2  Comportamientos que ponen en riesgo la vida e integridad. Corregido por el art. 1, Decreto 555 de 2017. Los siguientes comportamientos ponen en riesgo la vida e integridad de las personas, y, por lo tanto, son contrarios a la convivencia:
# 3  Comportamientos que ponen en riesgo la vida e integridad. Corregido por el art. 1, Decreto 555 de 2017. Los siguientes comportamientos ponen en riesgo la vida e integridad de las personas, y, por lo tanto, son contrarios a la convivencia:
# 4  Comportamientos que ponen en riesgo la vida e integridad. Corregido por el art. 1, Decreto 555 de 2017. Los siguientes comportamientos ponen en riesgo la vida e integridad de las personas, y, por lo tanto, son contrarios a la convivencia:
#
#   COD_COMPORTAMIENTO  \
# 0  Numeral 6
# 1  Numeral 6
# 2  Numeral 3
# 3  Numeral 1
# 4  Numeral 1
#
#                                                                                                                                                                                                                                                                DESCRIPCION_COMPORTAMIENTO  \
# 0  Portar armas, elementos cortantes, punzantes o semejantes, o sustancias peligrosas, en areas comunes o lugares abiertos al publico. Se exceptua a quien demuestre que tales elementos o sustancias constituyen una herramienta de su actividad deportiva, oficio, profesion o estudio.
# 1  Portar armas, elementos cortantes, punzantes o semejantes, o sustancias peligrosas, en areas comunes o lugares abiertos al publico. Se exceptua a quien demuestre que tales elementos o sustancias constituyen una herramienta de su actividad deportiva, oficio, profesion o estudio.
# 2  Agredir fisicamente a personas por cualquier medio.
# 3  Re?ir, incitar o incurrir en confrontaciones violentas que puedan derivar en agresiones fisicas.
# 4  Re?ir, incitar o incurrir en confrontaciones violentas que puedan derivar en agresiones fisicas.
#
#   TIPO_PRIORIZACION  \
# 0  RI?AS
# 1  RI?AS
# 2  RI?AS
# 3  RI?AS
# 4  RI?AS
#
#                                                                                                                          MEDIDA_CORRECTIVA_CODIGO  \
# 0  MULTA GENERAL TIPO 2; PROHIBICION DE INGRESO A EVENTOS QUE INVOLUCREN AGLOMERACIONES DE PUBLICO COMPLEJAS O NO COMPLEJAS, DESTRUCCION DE BIEN;
# 1  MULTA GENERAL TIPO 2; PROHIBICION DE INGRESO A EVENTOS QUE INVOLUCREN AGLOMERACIONES DE PUBLICO COMPLEJAS O NO COMPLEJAS, DESTRUCCION DE BIEN;
# 2  MULTA GENERAL TIPO 3;
# 3  MULTA GENERAL TIPO 2;
# 4  MULTA GENERAL TIPO 2;
#
#   ES_PEDAGOGICO  \
# 0  SI
# 1  SI
# 2  SI
# 3  SI
# 4  SI
#
#                                                                                                                                                                        STR_RELATO_HECHOS  \
# 0  MEDIANTE REGISTRO A PERSONA SE HAYA ARMA CORTOPUNZANTE EN LA PRETINA DEL PANTALON
# 1  EL CIUDADANO SE ENCONTRABA REALIZANDO O PORTANDO ARMAS CORTOPULSANTES EN LA DIRECCION ANTES MENCIONADA EN EL ESPACIO PUBLICO LO CUAL ES UN COMPORTAMIENTO CONTRARIO A LA CONVIVEVNCIA
# 2  AGREDIR FISICAMENTE AL SE?OR ANDRES GONZALES  CASA
# 3  RI?A EN VIA PUBLICA ARTICULO 27 NUMERAL 1
# 4  POR ENCONTRARSE EN ALTO GRADO DE EXALTACION  Y FOMENTANDO RI?A
#
#   ACTIVIDAD_COMERCIAL RAZON_SOCIAL  NUM_ID_HECHOS
# 0  -                   -            303
# 1  -                   -            511
# 2  -                   -            597
# 3  -                   -            626
# 4  -                   -            637

# %%
print("Tamaño:",data.shape)
print("size: ",data.size)
print("Porcentaje Celdas Vacias:",data.isna().mean().mean())
print("Porcentaje Celdas con valor '-':",(data == "-").mean().mean())
print("Filas duplicadas",data.duplicated().sum())
# Out:
# Tamaño: (267408, 31)
# size:  8289648
# Porcentaje Celdas Vacias: 1.20632383908219e-07
# /u01/user8/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning:
#
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# Porcentaje Celdas con valor '-': 0.06458368316724666
# Filas duplicadas 356

# %%
pd.DataFrame({"Tipo de dato":data.dtypes.values,
              "Celdas con valor '-'":(data == '-').sum().values,
              "Celdas vacías": data.isna().sum().values},
             index=data.columns)
# Out:
#                            Tipo de dato  Celdas con valor '-'  Celdas vacías
# EXPEDIENTE                  object       0                     0
# COMPARENDO                  object       0                     0
# FECHA                       object       0                     0
# HORA                        int64        0                     0
# ANIO                        int64        0                     0
# MES                         int64        0                     0
# LATITUD                     float64      0                     0
# LONGITUD                    float64      0                     0
# COD_LOCALIDAD               int64        0                     0
# NOMBRE_LOCALIDAD            object       0                     0
# COD_UPZ                     object       181                   0
# NOMBRE_UPZ                  object       181                   0
# COD_SCAT                    object       181                   0
# NOMBRE_SECTOR_CAT           object       181                   0
# COD_BARRIO                  object       181                   0
# NOMBRE_BARRIO               object       181                   0
# TIPO_SITIO                  object       0                     0
# RANGO_EDAD_1                object       115                   0
# TITULO                      object       0                     0
# CAPITULO                    object       0                     0
# ARTICULO                    int64        0                     0
# DESCRIPCION_ARTICULO        object       0                     0
# COD_COMPORTAMIENTO          object       0                     0
# DESCRIPCION_COMPORTAMIENTO  object       0                     0
# TIPO_PRIORIZACION           object       0                     0
# MEDIDA_CORRECTIVA_CODIGO    object       93                    0
# ES_PEDAGOGICO               object       0                     0
# STR_RELATO_HECHOS           object       0                     1
# ACTIVIDAD_COMERCIAL         object       267041                0
# RAZON_SOCIAL                object       267041                0
# NUM_ID_HECHOS               int64        0                     0

# %%
data.TIPO_PRIORIZACION.unique()
# Out:
# array(['RI?AS'], dtype=object)
