# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML
import calendar
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # 2. Rebuild missing data

# %%
localidadCodDictionaryNuse = {1:'USAQUEN',
                              2:'CHAPINERO',
                              3:'SANTA FE',
                              4:'SAN CRISTOBAL',
                              5:'USME',
                              6:'TUNJUELITO',
                              7:'BOSA',
                              8:'KENNEDY',
                              9:'FONTIBON',
                              10:'ENGATIVA',
                              11:'SUBA',
                              12:'BARRIOS UNIDOS',
                              13:'TEUSAQUILLO',
                              14:'LOS MARTIRES',
                              15:'ANTONIO NARIÑO',
                              16:'PUENTE ARANDA',
                              17:'CANDELARIA',
                              18:'RAFAEL URIBE URIBE',
                              19:'CIUDAD BOLIVAR',
                              20:'SUMAPAZ',
                              99:'SIN LOCALIZACION'}

# %% [markdown]
# ## Methods to rebuild

# %%
import import_ipynb
import ws_address
from selenium.common.exceptions import TimeoutException
import re
import unidecode
# Out:
# importing Jupyter notebook from ws_address.ipynb

# %%
def find_between( s, first, last ):
    try:
        start = s.index( first ) + len( first )
        end = s.index( last, start )
        return s[start:end]
    except ValueError:
        return ""

# %%
tags = ["Dirección ingresada: ","Dirección encontrada: ","Tipo dirección: ","Código postal: ","Sector catastral: ",
        "UPZ: ","Localidad: ","Latitud: ","Longitud: ","CHIP: "]
def parse_address_ws(ws_result):
    location = {}
    for idx in range(len(tags)-1):
        location[tags[idx].replace(': ','')] = find_between(ws_result,tags[idx],tags[idx+1])
    return location

# %%
def assign_upz(original_df,index,UPZ_ws_field):
    original_df.at[index,'COD_UPZ'] = find_between(UPZ_ws_field, '(', ')')
    original_df.at[index,'UPZ'] = find_between(UPZ_ws_field, '', ' (')

# %%
def get_cod_localidad(localidad_name):
    return [key  for (key, value) in localidadCodDictionaryNuse.items() if value == localidad_name][0]

# %%
def rebuild_location_in_nuse(original_df, index, driver):
    address = original_df.at[index,'STR_DIRECCION_INCIDENTE']
    print(address)
    result_ws = ws_address.web_scrap_address(driver,address)
    ws_address.delete_address(driver,address)

    if result_ws != "Not found":
        parsed_result = parse_address_ws(result_ws)
        print(parsed_result)
        if parsed_result["Dirección ingresada"] != address:
            return "Error loading address"
        else:            
            original_df.at[index,'LATITUD'] = float(parsed_result['Latitud'])
            original_df.at[index,'LONGITUD'] = float(parsed_result['Longitud'])
            parsed_localidad = parsed_result['Localidad']
            if parsed_localidad == 'ANTONIO NARIÑO':
                original_df.at[index,'LOCALIDAD'] = parsed_localidad
            else:
                original_df.at[index,'LOCALIDAD'] = unidecode.unidecode(parsed_localidad)
            original_df.at[index,'COD_LOCALIDAD'] = int(get_cod_localidad(original_df.at[index,'LOCALIDAD']))
            original_df.at[index,'SEC_CATASTRAL'] = parsed_result['Sector catastral']
            assign_upz(original_df,index,parsed_result['UPZ'])
            return "Rebuilt"
    else:
        return "Not processed"

# %%
def rebuild_address_in_nuse(original_df, index):
    log_text = original_df.at[index,'LOG_TEXT']
    address_found = re.search(address_regex,log_text)

    if address_found != None:
        parsed_address = clean_address(address_found)
        print(parsed_address.strip())
        original_df.at[index,'STR_DIRECCION_INCIDENTE'] = parsed_address.strip()
        return "Rebuilt"
    else:
        original_df.at[index,'STR_DIRECCION_INCIDENTE'] = 'ND'
        return "Not processed"

def clean_address(address_found):
    exclude_char_list = ['~','/','*','(',')']
    one_occurrence = address_found.group().split(',,,')[0].replace(',',' ')
    final_address = one_occurrence
    
    for char in exclude_char_list:
        if char in one_occurrence:
            final_address = final_address.split(char)[0]
            
    numbers_in_substring = re.sub('[^0-9]','', final_address)
    numbers_proportion = len(numbers_in_substring)/len(final_address)
    
    if numbers_proportion < 0.2:
        final_address = 'ND'
    
    return final_address

# %% [markdown]
# ## Implement rebuild methods

# %% [markdown]
# ### Rebuild location through address

# %%
data_location = '/home/combios/Documents/amreyesp/clean_nuse_data/rebuild_address_nuse_14012020.csv'
df_input = pd.read_csv(data_location,delimiter=",")

# %%
pd.DataFrame({"Tipo de dato":df_input.dtypes.values,
              "Celdas con valor '-'":(df_input == '-').sum().values,
              "Celdas con valor ''":(df_input == '').sum().values,
              "Celdas con valor ' '":(df_input == ' ').sum().values,
              "Celdas vacías": df_input.isna().sum().values},
             index=df_input.columns)
# Out:
# /home/combios/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
#                         Tipo de dato  Celdas con valor '-'  \
# STR_NUMERO_INTERNO       object       0
# FECHA                    object       0
# HORA                     int64        0
# ANIO                     int64        0
# MES                      int64        0
# COD_LOCALIDAD            object       6
# LOCALIDAD                object       6
# COD_UPZ                  object       51950
# UPZ                      object       51950
# COD_SEC_CATAST           object       51950
# SEC_CATASTRAL            object       51950
# COD_BARRIO               object       51950
# BARRIO                   object       51950
# TIPO_UNICO               int64        0
# TIPO_DETALLE             object       0
# LATITUD                  float64      0
# LONGITUD                 float64      0
# STR_DIRECCION_INCIDENTE  object       0
# ESTADO_INCIDENTE         object       0
# PERIODO_TS               object       0
# LOG_TEXT                 object       0
#
#                          Celdas con valor ''  Celdas con valor ' '  \
# STR_NUMERO_INTERNO       0                    0
# FECHA                    0                    0
# HORA                     0                    0
# ANIO                     0                    0
# MES                      0                    0
# COD_LOCALIDAD            0                    0
# LOCALIDAD                0                    0
# COD_UPZ                  0                    0
# UPZ                      0                    0
# COD_SEC_CATAST           0                    0
# SEC_CATASTRAL            0                    0
# COD_BARRIO               0                    0
# BARRIO                   0                    0
# TIPO_UNICO               0                    0
# TIPO_DETALLE             0                    0
# LATITUD                  0                    0
# LONGITUD                 0                    0
# STR_DIRECCION_INCIDENTE  0                    0
# ESTADO_INCIDENTE         0                    0
# PERIODO_TS               0                    0
# LOG_TEXT                 0                    0
#
#                          Celdas vacías
# STR_NUMERO_INTERNO       0
# FECHA                    0
# HORA                     0
# ANIO                     0
# MES                      0
# COD_LOCALIDAD            0
# LOCALIDAD                0
# COD_UPZ                  0
# UPZ                      0
# COD_SEC_CATAST           0
# SEC_CATASTRAL            0
# COD_BARRIO               0
# BARRIO                   0
# TIPO_UNICO               0
# TIPO_DETALLE             0
# LATITUD                  0
# LONGITUD                 0
# STR_DIRECCION_INCIDENTE  0
# ESTADO_INCIDENTE         103
# PERIODO_TS               0
# LOG_TEXT                 0

# %% [markdown]
# # Process small dataset to enhance web scraping performance

# %% [markdown]
# ## Get original idx list to process

# %%
data_location = '/home/combios/Documents/amreyesp/clean_nuse_data/rebuild_address_nuse_14012020.csv'
df_input = pd.read_csv(data_location,delimiter=",")
# Out:
# /home/combios/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df1 = df_input.loc[df_input['COD_UPZ'] == '-']
df2 = df_input.loc[df_input['UPZ'] == '-']
df3 = df_input.loc[df_input['COD_SEC_CATAST'] == '-']
df4 = df_input.loc[df_input['SEC_CATASTRAL'] == '-']
df5 = df_input.loc[df_input['COD_BARRIO'] == '-']
df6 = df_input.loc[df_input['BARRIO'] == '-']

# %%
df1.equals(df2) and df1.equals(df3) and df1.equals(df4) and df1.equals(df5) and df1.equals(df6)
# Out:
# True

# %%
#Try to rebuild 'sector catastral', 'UPZ', 'localidad', 'latitud', 'longitud' through address
df_empty_locations_with_address = df1.loc[df1['STR_DIRECCION_INCIDENTE'] != 'ND']
list_idx_rebuild_location = list(df_empty_locations_with_address.index.values)
len(list_idx_rebuild_location)
# Out:
# 48447

# %% [markdown]
# ## Iterate over small datasets

# %%
import time
from datetime import datetime

# %%
data_location = '/home/combios/Documents/amreyesp/clean_nuse_data/rebuild_locations_nuse_idx_39000_to_39999_24012020.csv'
df_input = pd.read_csv(data_location,delimiter=",")

# %%
df_output = df_input
idx_error_loading_address = []
num_reg_by_iter = 1000
registers_to_process = 8*num_reg_by_iter
rebuilt_registers = 0
registers_not_processed = 0
other_condition_counter = 0

file_path = '/home/combios/Documents/amreyesp/'

for i in range(40, 48):
    first_reg = i*num_reg_by_iter
    last_reg = ((i+1)*num_reg_by_iter)-1
    print(first_reg,' to ', last_reg)
    current_list_idx_rebuild = list_idx_rebuild_location[first_reg:last_reg]
    
    #Rebuild 'sector catastral', 'UPZ', 'localidad', 'latitud', 'longitud' using web scraping  
    url='https://mapas.bogota.gov.co'
    driver = ws_address.web_scrap_page(url)

    for index in current_list_idx_rebuild:
        state = rebuild_location_in_nuse(df_output, index, driver)
        if state == "Rebuilt":
            rebuilt_registers += 1
        elif state == "Not processed":
            registers_not_processed += 1
        elif state == "Error loading address":
            idx_error_loading_address.append(index)
        else:
            other_condition_counter += 1

        print('Rebuilt registers: ',rebuilt_registers,'/',registers_to_process)
        print('Registers not processed: ',registers_not_processed, '/', registers_to_process)
        
    time.sleep(30)
    # Save df output
    string_date = datetime.today().strftime('%d%m%Y')
    str_reg = str(first_reg) +'_to_'+ str(last_reg)
    file_name = "'" + file_path + 'rebuild_locations_nuse_idx_' + str_reg + '_' + string_date + ".csv'"
    df_output.to_csv(eval('r'+file_name),index=None)
    
    time.sleep(30)
    driver.quit()
# Out:
# 40000  to  40999
# KR 67 57 18
# {'Dirección ingresada': 'KR 67 57 18', 'Dirección encontrada': 'KR 67 60B 26', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111911', 'Sector catastral': 'MADELENA', 'UPZ': 'ARBORIZADORA (UPZ65)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.59178624200007', 'Longitud': '-74.1573715989999'}
# Rebuilt registers:  1 / 8000
# Registers not processed:  0 / 8000
# CL 90 91 22
# {'Dirección ingresada': 'CL 90 91 22', 'Dirección encontrada': 'AC 90 91 22', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '111021', 'Sector catastral': 'CIUDAD BACHUE', 'UPZ': 'MINUTO DE DIOS (UPZ29)', 'Localidad': 'ENGATIVÁ', 'Latitud': '4.71334272700005', 'Longitud': '-74.0978256469999'}
# Rebuilt registers:  2 / 8000
# Registers not processed:  0 / 8000
# CL 95 60A
# {'Dirección ingresada': 'CL 95 60A', 'Dirección encontrada': 'CL 94B 60A 0', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111211', 'Sector catastral': 'RIONEGRO', 'UPZ': 'LOS ANDES (UPZ21)', 'Localidad': 'BARRIOS UNIDOS', 'Latitud': '4.68401231437206', 'Longitud': '-74.0667858226486'}
# Rebuilt registers:  3 / 8000
# Registers not processed:  0 / 8000
# KR 5 ESTE 49D SUR 52
# Rebuilt registers:  3 / 8000
# Registers not processed:  1 / 8000
# AK 80 14 74
# {'Dirección ingresada': 'AK 80 14 74', 'Dirección encontrada': 'AK 80 14 72', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '110821', 'Sector catastral': 'VISION DE ORIENTE', 'UPZ': 'CASTILLA (UPZ46)', 'Localidad': 'KENNEDY', 'Latitud': '4.65231512600008', 'Longitud': '-74.1352413119999'}
# Rebuilt registers:  4 / 8000
# Registers not processed:  1 / 8000
# DG 98 SUR 4A 29
# {'Dirección ingresada': 'DG 98 SUR 4A 29', 'Dirección encontrada': 'CL 98 S 5 29', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '110541', 'Sector catastral': 'SERRANIAS I', 'UPZ': 'COMUNEROS (UPZ58)', 'Localidad': 'USME', 'Latitud': '4.4980186795696', 'Longitud': '-74.1132834324791'}
# Rebuilt registers:  5 / 8000
# Registers not processed:  1 / 8000
# KR 16C 64A SUR 30
# {'Dirección ingresada': 'KR 16C 64A SUR 30', 'Dirección encontrada': 'KR 16C 64A 30 S', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '111961', 'Sector catastral': 'MEXICO', 'UPZ': 'LUCERO (UPZ67)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.55404711300008', 'Longitud': '-74.1357816549999'}
# Rebuilt registers:  6 / 8000
# Registers not processed:  1 / 8000
# TV 2C 25B SUR 56
# {'Dirección ingresada': 'TV 2C 25B SUR 56', 'Dirección encontrada': 'TV 2C 25B S 56', 'Tipo dirección': 'Dirección Antigua', 'Código postal': '110421', 'Sector catastral': 'GRANADA SUR', 'UPZ': '20 DE JULIO (UPZ34)', 'Localidad': 'SAN CRISTÓBAL', 'Latitud': '4.56909150020421', 'Longitud': '-74.0930988990913'}
# Rebuilt registers:  7 / 8000
# Registers not processed:  1 / 8000
# KR 83 39 SUR 09
# {'Dirección ingresada': 'KR 83 39 SUR 09', 'Dirección encontrada': 'KR 83 39 09 S', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '110851', 'Sector catastral': 'LLANO GRANDE', 'UPZ': 'CORABASTOS (UPZ80)', 'Localidad': 'KENNEDY', 'Latitud': '4.63257363900004', 'Longitud': '-74.1635645569999'}
# Rebuilt registers:  8 / 8000
# Registers not processed:  1 / 8000
# KR 88C 43 SUR 59
# {'Dirección ingresada': 'KR 88C 43 SUR 59', 'Dirección encontrada': 'KR 88C 43 53 S', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '110881', 'Sector catastral': 'LAS MARGARITAS', 'UPZ': 'LAS MARGARITAS (UPZ83)', 'Localidad': 'KENNEDY', 'Latitud': '4.63367399900005', 'Longitud': '-74.1745711319999'}
# Rebuilt registers:  9 / 8000
# Registers not processed:  1 / 8000
# CL 47C SUR 1C ESTE 14
# Rebuilt registers:  9 / 8000
# Registers not processed:  2 / 8000
# DG 69 SUR 18C 65
# {'Dirección ingresada': 'DG 69 SUR 18C 65', 'Dirección encontrada': 'CL 69 S 18B 75', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111961', 'Sector catastral': 'BELLAVISTA LUCERO ALTO', 'UPZ': 'LUCERO (UPZ67)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.54903585800008', 'Longitud': '-74.145932705'}
# Rebuilt registers:  10 / 8000
# Registers not processed:  2 / 8000
# CL 90 95 63
# {'Dirección ingresada': 'CL 90 95 63', 'Dirección encontrada': 'AC 90 95 53', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111021', 'Sector catastral': 'CIUDAD BACHUE II', 'UPZ': 'MINUTO DE DIOS (UPZ29)', 'Localidad': 'ENGATIVÁ', 'Latitud': '4.71582496000008', 'Longitud': '-74.1010366829999'}
# Rebuilt registers:  11 / 8000
# Registers not processed:  2 / 8000
# DG 70A SUR 45 21
# {'Dirección ingresada': 'DG 70A SUR 45 21', 'Dirección encontrada': 'DG 70A S 45 33', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111931', 'Sector catastral': 'LA PRADERA', 'UPZ': 'JERUSALEM (UPZ70)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.57032016200009', 'Longitud': '-74.1598778349999'}
# Rebuilt registers:  12 / 8000
# Registers not processed:  2 / 8000
# CL 52G SUR 29 46
# {'Dirección ingresada': 'CL 52G SUR 29 46', 'Dirección encontrada': 'CL 52G S 29 46', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '110611', 'Sector catastral': 'SAN VICENTE FERRER', 'UPZ': 'VENECIA (UPZ42)', 'Localidad': 'TUNJUELITO', 'Latitud': '4.58107871900006', 'Longitud': '-74.1378962449999'}
# Rebuilt registers:  13 / 8000
# Registers not processed:  2 / 8000
# CL 73 SUR 27B 35
# {'Dirección ingresada': 'CL 73 SUR 27B 35', 'Dirección encontrada': 'DG 73 S 27B 35', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111951', 'Sector catastral': 'BELLA FLOR', 'UPZ': 'LUCERO (UPZ67)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.54615115800684', 'Longitud': '-74.1613379962961'}
# Rebuilt registers:  14 / 8000
# Registers not processed:  2 / 8000
# CL 64 SUR 20 F 14
# {'Dirección ingresada': 'CL 64 SUR 20 F 14', 'Dirección encontrada': 'CL 64 S 20F 04', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111941', 'Sector catastral': 'LAS ACACIAS', 'UPZ': 'SAN FRANCISCO (UPZ66)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.56483123700008', 'Longitud': '-74.1461298859999'}
# Rebuilt registers:  15 / 8000
# Registers not processed:  2 / 8000
# KR 68 3 43
# {'Dirección ingresada': 'KR 68 3 43', 'Dirección encontrada': 'AK 68 3 05', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '110831', 'Sector catastral': 'HIPOTECHO SUR', 'UPZ': 'AMERICAS (UPZ44)', 'Localidad': 'KENNEDY', 'Latitud': '4.62467233900009', 'Longitud': '-74.1243543839999'}
# Rebuilt registers:  16 / 8000
# Registers not processed:  2 / 8000
# CL 61A SUR 18R 23
# {'Dirección ingresada': 'CL 61A SUR 18R 23', 'Dirección encontrada': 'CL 61 BIS A S 18R 27', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111951', 'Sector catastral': 'LUCERO ALTO', 'UPZ': 'LUCERO (UPZ67)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.56062346100009', 'Longitud': '-74.1401177909999'}
# Rebuilt registers:  17 / 8000
# Registers not processed:  2 / 8000
# CL 63 13 03
# {'Dirección ingresada': 'CL 63 13 03', 'Dirección encontrada': 'AC 63 13 07', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '110231', 'Sector catastral': 'CHAPINERO CENTRAL', 'UPZ': 'CHAPINERO (UPZ99)', 'Localidad': 'CHAPINERO', 'Latitud': '4.64935603200007', 'Longitud': '-74.0637442999999'}
# Rebuilt registers:  18 / 8000
# Registers not processed:  2 / 8000
# CL 70B SUR 87D 84
# {'Dirección ingresada': 'CL 70B SUR 87D 84', 'Dirección encontrada': 'CL 70A BIS S 87C 26', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '110721', 'Sector catastral': 'LA INDEPENDENCIA', 'UPZ': 'BOSA OCCIDENTAL (UPZ84)', 'Localidad': 'BOSA', 'Latitud': '4.62098566700007', 'Longitud': '-74.1966988719999'}
# Rebuilt registers:  19 / 8000
# Registers not processed:  2 / 8000
# CL 51SUR 78G 67
# {'Dirección ingresada': 'CL 51SUR 78G 67', 'Dirección encontrada': 'CL 51 S 78G 67', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '110861', 'Sector catastral': 'CATALINA', 'UPZ': 'TIMIZA (UPZ48)', 'Localidad': 'KENNEDY', 'Latitud': '4.61195701200006', 'Longitud': '-74.1679161019999'}
# Rebuilt registers:  20 / 8000
# Registers not processed:  2 / 8000
# KR 119 69 09
# {'Dirección ingresada': 'KR 119 69 09', 'Dirección encontrada': 'KR 119 69 09', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '111031', 'Sector catastral': 'LA FAENA', 'UPZ': 'ENGATIVA (UPZ74)', 'Localidad': 'ENGATIVÁ', 'Latitud': '4.71493878700005', 'Longitud': '-74.1374439399999'}
# Rebuilt registers:  21 / 8000
# Registers not processed:  2 / 8000
# CL 32 10 ESTE 97
# Rebuilt registers:  21 / 8000
# Registers not processed:  3 / 8000
# CL 2 82 58
# {'Dirección ingresada': 'CL 2 82 58', 'Dirección encontrada': 'CL 2 82 58', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '110851', 'Sector catastral': 'MARIA PAZ', 'UPZ': 'CORABASTOS (UPZ80)', 'Localidad': 'KENNEDY', 'Latitud': '4.63782553000004', 'Longitud': '-74.1567443319999'}
# Rebuilt registers:  22 / 8000
# Registers not processed:  3 / 8000
# KR 12B 8 SUR
# {'Dirección ingresada': 'KR 12B 8 SUR', 'Dirección encontrada': 'KR 12B 8 00 S', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '111511', 'Sector catastral': 'CIUDAD BERNA', 'UPZ': 'CIUDAD JARDIN (UPZ35)', 'Localidad': 'ANTONIO NARIÑO', 'Latitud': '4.58618765200009', 'Longitud': '-74.0915820939999'}
# Rebuilt registers:  23 / 8000
# Registers not processed:  3 / 8000
# KR 28 7 85
# {'Dirección ingresada': 'KR 28 7 85', 'Dirección encontrada': 'KR 28 7 83', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111411', 'Sector catastral': 'RICAURTE', 'UPZ': 'LA SABANA (UPZ102)', 'Localidad': 'LOS MÁRTIRES', 'Latitud': '4.60705557200009', 'Longitud': '-74.0949521349999'}
# Rebuilt registers:  24 / 8000
# Registers not processed:  3 / 8000
# KR 18L 65F SUR 07
# {'Dirección ingresada': 'KR 18L 65F SUR 07', 'Dirección encontrada': 'KR 18L 65D S 7', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111951', 'Sector catastral': 'SUMAPAZ', 'UPZ': 'LUCERO (UPZ67)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.55328434790719', 'Longitud': '-74.1441063759192'}
# Rebuilt registers:  25 / 8000
# Registers not processed:  3 / 8000
# KR 77K 57D SUR 50
# {'Dirección ingresada': 'KR 77K 57D SUR 50', 'Dirección encontrada': 'KR 77K 57D 50 S', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '110861', 'Sector catastral': 'LA CECILIA', 'UPZ': 'TIMIZA (UPZ48)', 'Localidad': 'KENNEDY', 'Latitud': '4.60603781100008', 'Longitud': '-74.1734932529999'}
# Rebuilt registers:  26 / 8000
# Registers not processed:  3 / 8000
# KR 105 70A 15
# {'Dirección ingresada': 'KR 105 70A 15', 'Dirección encontrada': 'KR 105 70 15', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111041', 'Sector catastral': 'VILLA SAGRARIO', 'UPZ': 'GARCES NAVAS (UPZ73)', 'Localidad': 'ENGATIVÁ', 'Latitud': '4.70375159476643', 'Longitud': '-74.1215369418454'}
# Rebuilt registers:  27 / 8000
# Registers not processed:  3 / 8000
# CL 27 SUR 51C 12
# {'Dirección ingresada': 'CL 27 SUR 51C 12', 'Dirección encontrada': 'CL 27 S 51D 12', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111621', 'Sector catastral': 'ALCALA', 'UPZ': 'MUZU (UPZ41)', 'Localidad': 'PUENTE ARANDA', 'Latitud': '4.60454164000009', 'Longitud': '-74.1250857629999'}
# Rebuilt registers:  28 / 8000
# Registers not processed:  3 / 8000
# CL 96B 19 30
# {'Dirección ingresada': 'CL 96B 19 30', 'Dirección encontrada': 'CL 96 19A 30', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '110221', 'Sector catastral': 'CHICO NORTE III SECTOR', 'UPZ': 'CHICO LAGO (UPZ97)', 'Localidad': 'CHAPINERO', 'Latitud': '4.68360306514485', 'Longitud': '-74.0538550156664'}
# Rebuilt registers:  29 / 8000
# Registers not processed:  3 / 8000
# CL 130 159D 17
# {'Dirección ingresada': 'CL 130 159D 17', 'Dirección encontrada': 'CL 130 159C 19', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111151', 'Sector catastral': 'SANTA CECILIA', 'UPZ': 'TIBABUYES (UPZ71)', 'Localidad': 'SUBA', 'Latitud': '4.73790289200008', 'Longitud': '-74.1289551639999'}
# Rebuilt registers:  30 / 8000
# Registers not processed:  3 / 8000
# TV 32 30B SUR 80
# {'Dirección ingresada': 'TV 32 30B SUR 80', 'Dirección encontrada': 'TV 33A 31 S 80', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111511', 'Sector catastral': 'EDUARDO FREY', 'UPZ': 'RESTREPO (UPZ38)', 'Localidad': 'ANTONIO NARIÑO', 'Latitud': '4.59203135532128', 'Longitud': '-74.1169884438091'}
# Rebuilt registers:  31 / 8000
# Registers not processed:  3 / 8000
# KR 94D 87C
# {'Dirección ingresada': 'KR 94D 87C', 'Dirección encontrada': 'TV 94D 87C 0', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111021', 'Sector catastral': 'QUIRIGUA I', 'UPZ': 'MINUTO DE DIOS (UPZ29)', 'Localidad': 'ENGATIVÁ', 'Latitud': '4.71208134927942', 'Longitud': '-74.0998843999634'}
# Rebuilt registers:  32 / 8000
# Registers not processed:  3 / 8000
# KR 2 44 15
# {'Dirección ingresada': 'KR 2 44 15', 'Dirección encontrada': 'KR 2 44 20', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '110231', 'Sector catastral': 'SIBERIA CENTRAL', 'UPZ': 'PARDO RUBIO (UPZ90)', 'Localidad': 'CHAPINERO', 'Latitud': '4.63040780500006', 'Longitud': '-74.0612607299999'}
# Rebuilt registers:  33 / 8000
# Registers not processed:  3 / 8000
# TV 72N 35 SUR 09
# {'Dirección ingresada': 'TV 72N 35 SUR 09', 'Dirección encontrada': 'TV 72N 35 09 S', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '110851', 'Sector catastral': 'CIUDAD KENNEDY ORIENTAL', 'UPZ': 'KENNEDY CENTRAL (UPZ47)', 'Localidad': 'KENNEDY', 'Latitud': '4.61957543800008', 'Longitud': '-74.1434805939999'}
# Rebuilt registers:  34 / 8000
# Registers not processed:  3 / 8000
# KR 1F BIS ESTE 68B SUR 51
# Rebuilt registers:  34 / 8000
# Registers not processed:  4 / 8000
# CL 154 114 51
# {'Dirección ingresada': 'CL 154 114 51', 'Dirección encontrada': 'CL 154 114 47', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111161', 'Sector catastral': 'TUNA BAJA', 'UPZ': 'SUBA (UPZ27)', 'Localidad': 'SUBA', 'Latitud': '4.75860485900006', 'Longitud': '-74.0979992059999'}
# Rebuilt registers:  35 / 8000
# Registers not processed:  4 / 8000
# KR 62B 4 67
# {'Dirección ingresada': 'KR 62B 4 67', 'Dirección encontrada': 'KR 62 4D 67', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111611', 'Sector catastral': 'LA TRINIDAD', 'UPZ': 'SAN RAFAEL (UPZ43)', 'Localidad': 'PUENTE ARANDA', 'Latitud': '4.62492075927517', 'Longitud': '-74.1188045092255'}
# Rebuilt registers:  36 / 8000
# Registers not processed:  4 / 8000
# KR 6 36A SUR 65
# {'Dirección ingresada': 'KR 6 36A SUR 65', 'Dirección encontrada': 'KR 6A 36 S 65', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '110431', 'Sector catastral': 'LAS LOMAS', 'UPZ': '20 DE JULIO (UPZ34)', 'Localidad': 'SAN CRISTÓBAL', 'Latitud': '4.56259312385615', 'Longitud': '-74.1018875884161'}
# Rebuilt registers:  37 / 8000
# Registers not processed:  4 / 8000
# CL 116 SUR 1A ESTE 34
# Rebuilt registers:  37 / 8000
# Registers not processed:  5 / 8000
# KR 126 63A 45
# {'Dirección ingresada': 'KR 126 63A 45', 'Dirección encontrada': 'KR 126 63K 45', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111031', 'Sector catastral': 'ENGATIVA ZONA URBANA', 'UPZ': 'ENGATIVA (UPZ74)', 'Localidad': 'ENGATIVÁ', 'Latitud': '4.71675605038847', 'Longitud': '-74.1434614953419'}
# Rebuilt registers:  38 / 8000
# Registers not processed:  5 / 8000
# DG 48I SUR 3 13
# {'Dirección ingresada': 'DG 48I SUR 3 13', 'Dirección encontrada': 'DG 48I S 3 13', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '111831', 'Sector catastral': 'LOS MOLINOS', 'UPZ': 'MARRUECOS (UPZ54)', 'Localidad': 'RAFAEL URIBE URIBE', 'Latitud': '4.55741559900008', 'Longitud': '-74.1072546469999'}
# Rebuilt registers:  39 / 8000
# Registers not processed:  5 / 8000
# CL 39 B BIS 72F 52
# {'Dirección ingresada': 'CL 39 B BIS 72F 52', 'Dirección encontrada': 'CL 40H BIS 72M 52', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '110841', 'Sector catastral': 'TIMIZA A', 'UPZ': 'TIMIZA (UPZ48)', 'Localidad': 'KENNEDY', 'Latitud': '4.60906318942021', 'Longitud': '-74.1520333974523'}
# Rebuilt registers:  40 / 8000
# Registers not processed:  5 / 8000
# CL 38C SUR 73A 13
# {'Dirección ingresada': 'CL 38C SUR 73A 13', 'Dirección encontrada': 'CL 38C S 73A 13', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '110841', 'Sector catastral': 'TIMIZA', 'UPZ': 'CARVAJAL (UPZ45)', 'Localidad': 'KENNEDY', 'Latitud': '4.61620945200008', 'Longitud': '-74.1490510639999'}
# Rebuilt registers:  41 / 8000
# Registers not processed:  5 / 8000
# KR 14 68 SUR 38
# {'Dirección ingresada': 'KR 14 68 SUR 38', 'Dirección encontrada': 'KR 14 68A S 38', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '110521', 'Sector catastral': 'BARRANQUILLITA', 'UPZ': 'GRAN YOMASA (UPZ57)', 'Localidad': 'USME', 'Latitud': '4.52680177689746', 'Longitud': '-74.1195110374634'}
# Rebuilt registers:  42 / 8000
# Registers not processed:  5 / 8000
# KR 14A 83 84
# {'Dirección ingresada': 'KR 14A 83 84', 'Dirección encontrada': 'KR 14A 83 76', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '110221', 'Sector catastral': 'EL RETIRO', 'UPZ': 'CHICO LAGO (UPZ97)', 'Localidad': 'CHAPINERO', 'Latitud': '4.66906802100004', 'Longitud': '-74.0550899449999'}
# Rebuilt registers:  43 / 8000
# Registers not processed:  5 / 8000
# KR 10A 48 SUR 28
# {'Dirección ingresada': 'KR 10A 48 SUR 28', 'Dirección encontrada': 'KR 10A 48 28 S', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '111831', 'Sector catastral': 'ARBOLEDA SUR', 'UPZ': 'MARRUECOS (UPZ54)', 'Localidad': 'RAFAEL URIBE URIBE', 'Latitud': '4.56234386400007', 'Longitud': '-74.1138918069999'}
# Rebuilt registers:  44 / 8000
# Registers not processed:  5 / 8000
# DG 32A BIS B SUR 12D 26
# {'Dirección ingresada': 'DG 32A BIS B SUR 12D 26', 'Dirección encontrada': 'DG 32A BIS B S 12D 26', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '111821', 'Sector catastral': 'GRANJAS DE SANTA SOFIA', 'UPZ': 'MARCO FIDEL SUAREZ (UPZ53)', 'Localidad': 'RAFAEL URIBE URIBE', 'Latitud': '4.56987344400005', 'Longitud': '-74.1101941929999'}
# Rebuilt registers:  45 / 8000
# Registers not processed:  5 / 8000
# CL 58C SUR 42 28
# {'Dirección ingresada': 'CL 58C SUR 42 28', 'Dirección encontrada': 'CL 58C S 42 28', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '111911', 'Sector catastral': 'ARBORIZADORA BAJA', 'UPZ': 'ARBORIZADORA (UPZ65)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.57469767100008', 'Longitud': '-74.1499380389999'}
# Rebuilt registers:  46 / 8000
# Registers not processed:  5 / 8000
# KR 98C 38 SUR
# {'Dirección ingresada': 'KR 98C 38 SUR', 'Dirección encontrada': 'KR 98C BIS 38 S 0', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '110871', 'Sector catastral': 'GALAN', 'UPZ': 'PATIO BONITO (UPZ82)', 'Localidad': 'KENNEDY', 'Latitud': '4.64939262579402', 'Longitud': '-74.1741080189866'}
# Rebuilt registers:  47 / 8000
# Registers not processed:  5 / 8000
# CL 18A 112 70
# {'Dirección ingresada': 'CL 18A 112 70', 'Dirección encontrada': 'CL 18C 112 30', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '110921', 'Sector catastral': 'VILLA CARMENZA', 'UPZ': 'FONTIBON (UPZ75)', 'Localidad': 'FONTIBÓN', 'Latitud': '4.68220382700008', 'Longitud': '-74.1505610169999'}
# Rebuilt registers:  48 / 8000
# Registers not processed:  5 / 8000
# CL 136 56C 22
# {'Dirección ingresada': 'CL 136 56C 22', 'Dirección encontrada': 'CL 136 56A 18', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111111', 'Sector catastral': 'SAN JOSE DEL PRADO', 'UPZ': 'NIZA (UPZ24)', 'Localidad': 'SUBA', 'Latitud': '4.72487231700006', 'Longitud': '-74.0635200969999'}
# Rebuilt registers:  49 / 8000
# Registers not processed:  5 / 8000
# CL 23J BIS 97 49
# {'Dirección ingresada': 'CL 23J BIS 97 49', 'Dirección encontrada': 'CL 23J BIS 97 53', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '110911', 'Sector catastral': 'SAN JOSE DE FONTIBON', 'UPZ': 'FONTIBON (UPZ75)', 'Localidad': 'FONTIBÓN', 'Latitud': '4.67998743700008', 'Longitud': '-74.1335630269999'}
# Rebuilt registers:  50 / 8000
# Registers not processed:  5 / 8000
# CL 6A SUR 4A 20
# {'Dirección ingresada': 'CL 6A SUR 4A 20', 'Dirección encontrada': 'CL 6A S 4 20', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '110411', 'Sector catastral': 'BUENOS AIRES', 'UPZ': 'SOSIEGO (UPZ33)', 'Localidad': 'SAN CRISTÓBAL', 'Latitud': '4.58085374528567', 'Longitud': '-74.0824920829993'}
# Rebuilt registers:  51 / 8000
# Registers not processed:  5 / 8000
# KR 75 62C SUR 20
# {'Dirección ingresada': 'KR 75 62C SUR 20', 'Dirección encontrada': 'KR 75 62D S 20', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111921', 'Sector catastral': 'MARIA CANO', 'UPZ': 'ISMAEL PERDOMO (UPZ69)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.58951516480684', 'Longitud': '-74.1749122667338'}
# Rebuilt registers:  52 / 8000
# Registers not processed:  5 / 8000
# CL 133 100 09
# {'Dirección ingresada': 'CL 133 100 09', 'Dirección encontrada': 'CL 133A 100 9', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111131', 'Sector catastral': 'LA CHUCUA', 'UPZ': 'EL RINCON (UPZ28)', 'Localidad': 'SUBA', 'Latitud': '4.73613743464492', 'Longitud': '-74.0945554404867'}
# Rebuilt registers:  53 / 8000
# Registers not processed:  5 / 8000
# CL 69 BIS A 89 BIS A 01
# {'Dirección ingresada': 'CL 69 BIS A 89 BIS A 01', 'Dirección encontrada': 'CL 69A BIS 89A 1', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111051', 'Sector catastral': 'FLORIDA BLANCA', 'UPZ': 'BOYACA REAL (UPZ30)', 'Localidad': 'ENGATIVÁ', 'Latitud': '4.69394040548762', 'Longitud': '-74.1104829604257'}
# Rebuilt registers:  54 / 8000
# Registers not processed:  5 / 8000
# CL 132D 151A 81
# {'Dirección ingresada': 'CL 132D 151A 81', 'Dirección encontrada': 'CL 132D 151A 81', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '111151', 'Sector catastral': 'LISBOA', 'UPZ': 'TIBABUYES (UPZ71)', 'Localidad': 'SUBA', 'Latitud': '4.74316311800004', 'Longitud': '-74.1224987989999'}
# Rebuilt registers:  55 / 8000
# Registers not processed:  5 / 8000
# DG 52C SUR 53 55
# {'Dirección ingresada': 'DG 52C SUR 53 55', 'Dirección encontrada': 'DG 52B S 53 55', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '110611', 'Sector catastral': 'VENECIA', 'UPZ': 'VENECIA (UPZ42)', 'Localidad': 'TUNJUELITO', 'Latitud': '4.58954357726216', 'Longitud': '-74.1395740983909'}
# Rebuilt registers:  56 / 8000
# Registers not processed:  5 / 8000
# CL 48B SUR 23 83
# {'Dirección ingresada': 'CL 48B SUR 23 83', 'Dirección encontrada': 'CL 48B S 23 83', 'Tipo dirección': 'Dirección Antigua', 'Código postal': '110621', 'Sector catastral': 'PARQUE EL TUNAL', 'UPZ': 'VENECIA (UPZ42)', 'Localidad': 'TUNJUELITO', 'Latitud': '4.57642022369682', 'Longitud': '-74.1306461402191'}
# Rebuilt registers:  57 / 8000
# Registers not processed:  5 / 8000
# KR 24 41 45
# {'Dirección ingresada': 'KR 24 41 45', 'Dirección encontrada': 'AK 24 41 43', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111311', 'Sector catastral': 'LA SOLEDAD', 'UPZ': 'TEUSAQUILLO (UPZ101)', 'Localidad': 'TEUSAQUILLO', 'Latitud': '4.63190685000006', 'Longitud': '-74.0752665599999'}
# Rebuilt registers:  58 / 8000
# Registers not processed:  5 / 8000
# KR 1F BIS ESTE 68B SUR 51
# Rebuilt registers:  58 / 8000
# Registers not processed:  6 / 8000
# CL 3A 68 40
# {'Dirección ingresada': 'CL 3A 68 40', 'Dirección encontrada': 'CL 3 BIS 68 40', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '110831', 'Sector catastral': 'HIPOTECHO SUR', 'UPZ': 'AMERICAS (UPZ44)', 'Localidad': 'KENNEDY', 'Latitud': '4.62502177400006', 'Longitud': '-74.1245924899999'}
# Rebuilt registers:  59 / 8000
# Registers not processed:  6 / 8000
# DG 85 77 80
# {'Dirección ingresada': 'DG 85 77 80', 'Dirección encontrada': 'DG 85 77 78', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111021', 'Sector catastral': 'PARIS GAITAN', 'UPZ': 'MINUTO DE DIOS (UPZ29)', 'Localidad': 'ENGATIVÁ', 'Latitud': '4.70659823300008', 'Longitud': '-74.0947092469999'}
# Rebuilt registers:  60 / 8000
# Registers not processed:  6 / 8000
# TV 96A 77A 06
# {'Dirección ingresada': 'TV 96A 77A 06', 'Dirección encontrada': 'TV 96A 77B 6', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111041', 'Sector catastral': 'EL MADRIGAL', 'UPZ': 'GARCES NAVAS (UPZ73)', 'Localidad': 'ENGATIVÁ', 'Latitud': '4.70879322097828', 'Longitud': '-74.1124032213803'}
# Rebuilt registers:  61 / 8000
# Registers not processed:  6 / 8000
# KR 56 159 19
# {'Dirección ingresada': 'KR 56 159 19', 'Dirección encontrada': 'KR 56 159 27', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111156', 'Sector catastral': 'CANTAGALLO', 'UPZ': 'BRITALIA (UPZ18)', 'Localidad': 'SUBA', 'Latitud': '4.74189230900009', 'Longitud': '-74.0592334399999'}
# Rebuilt registers:  62 / 8000
# Registers not processed:  6 / 8000
# DG 45A SUR 13 16
# {'Dirección ingresada': 'DG 45A SUR 13 16', 'Dirección encontrada': 'DG 45C S 13 16', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111821', 'Sector catastral': 'MARCO FIDEL SUAREZ', 'UPZ': 'MARCO FIDEL SUAREZ (UPZ53)', 'Localidad': 'RAFAEL URIBE URIBE', 'Latitud': '4.56947000202102', 'Longitud': '-74.1177360049103'}
# Rebuilt registers:  63 / 8000
# Registers not processed:  6 / 8000
# KR 15 108 90
# {'Dirección ingresada': 'KR 15 108 90', 'Dirección encontrada': 'AK 15 108 50', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '110111', 'Sector catastral': 'MOLINOS NORTE', 'UPZ': 'SANTA BARBARA (UPZ16)', 'Localidad': 'USAQUÉN', 'Latitud': '4.69234380800009', 'Longitud': '-74.0446814809999'}
# Rebuilt registers:  64 / 8000
# Registers not processed:  6 / 8000
# KR 32 64 SUR 52
# {'Dirección ingresada': 'KR 32 64 SUR 52', 'Dirección encontrada': 'KR 32 64 40 S', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111941', 'Sector catastral': 'CANDELARIA LA NUEVA', 'UPZ': 'SAN FRANCISCO (UPZ66)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.56887431600006', 'Longitud': '-74.1503555039999'}
# Rebuilt registers:  65 / 8000
# Registers not processed:  6 / 8000
# CL 133C 155 03
# {'Dirección ingresada': 'CL 133C 155 03', 'Dirección encontrada': 'CL 133 154A 03', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111151', 'Sector catastral': 'SANTA CECILIA', 'UPZ': 'TIBABUYES (UPZ71)', 'Localidad': 'SUBA', 'Latitud': '4.74248530500006', 'Longitud': '-74.1251210579999'}
# Rebuilt registers:  66 / 8000
# Registers not processed:  6 / 8000
# KR 40A 16 SUR 64
# {'Dirección ingresada': 'KR 40A 16 SUR 64', 'Dirección encontrada': 'KR 40A 16 64 S', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '111631', 'Sector catastral': 'REMANSO SUR', 'UPZ': 'CIUDAD MONTES (UPZ40)', 'Localidad': 'PUENTE ARANDA', 'Latitud': '4.60290175200009', 'Longitud': '-74.1181853799999'}
# Rebuilt registers:  67 / 8000
# Registers not processed:  6 / 8000
# KR 14 68 SUR 38
# {'Dirección ingresada': 'KR 14 68 SUR 38', 'Dirección encontrada': 'KR 14 68A S 38', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '110521', 'Sector catastral': 'BARRANQUILLITA', 'UPZ': 'GRAN YOMASA (UPZ57)', 'Localidad': 'USME', 'Latitud': '4.52680177689746', 'Longitud': '-74.1195110374634'}
# Rebuilt registers:  68 / 8000
# Registers not processed:  6 / 8000
# CL 133A BIS 111A 17
# {'Dirección ingresada': 'CL 133A BIS 111A 17', 'Dirección encontrada': 'CL 133A BIS 111A 17', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '111141', 'Sector catastral': 'VILLA MARIA', 'UPZ': 'EL RINCON (UPZ28)', 'Localidad': 'SUBA', 'Latitud': '4.73974015300007', 'Longitud': '-74.104277883'}
# Rebuilt registers:  69 / 8000
# Registers not processed:  6 / 8000
# KR 78P 44 SUR 48
# {'Dirección ingresada': 'KR 78P 44 SUR 48', 'Dirección encontrada': 'KR 78P 44 48 S', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '110861', 'Sector catastral': 'PASTRANA', 'UPZ': 'KENNEDY CENTRAL (UPZ47)', 'Localidad': 'KENNEDY', 'Latitud': '4.61713394100008', 'Longitud': '-74.1651420499999'}
# Rebuilt registers:  70 / 8000
# Registers not processed:  6 / 8000
# KR 17B BIS 66 SUR 12
# {'Dirección ingresada': 'KR 17B BIS 66 SUR 12', 'Dirección encontrada': 'KR 17B BIS 66 12 S', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '111961', 'Sector catastral': 'LA ALAMEDA', 'UPZ': 'LUCERO (UPZ67)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.55206842400008', 'Longitud': '-74.1381875679999'}
# Rebuilt registers:  71 / 8000
# Registers not processed:  6 / 8000
# DG 85 75 06
# {'Dirección ingresada': 'DG 85 75 06', 'Dirección encontrada': 'DG 84A 75A 6', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111021', 'Sector catastral': 'LA SERENA', 'UPZ': 'MINUTO DE DIOS (UPZ29)', 'Localidad': 'ENGATIVÁ', 'Latitud': '4.70604678653708', 'Longitud': '-74.0917777228563'}
# Rebuilt registers:  72 / 8000
# Registers not processed:  6 / 8000
# CL 65A SUR 76C 45
# {'Dirección ingresada': 'CL 65A SUR 76C 45', 'Dirección encontrada': 'CL 65A S 76C 45', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '111921', 'Sector catastral': 'ESPINO I', 'UPZ': 'ISMAEL PERDOMO (UPZ69)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.58269370100004', 'Longitud': '-74.179324516'}
# Rebuilt registers:  73 / 8000
# Registers not processed:  6 / 8000
# KR 94 130 51
# Rebuilt registers:  73 / 8000
# Registers not processed:  7 / 8000
# KR 27B 71 SUR 00
# {'Dirección ingresada': 'KR 94 130 51', 'Dirección encontrada': 'KR 94 130 27', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111131', 'Sector catastral': 'EL RINCON NORTE', 'UPZ': 'EL RINCON (UPZ28)', 'Localidad': 'SUBA', 'Latitud': '4.72770582300006', 'Longitud': '-74.0916083639999'}
# Rebuilt registers:  73 / 8000
# Registers not processed:  7 / 8000
# KR 17B BIS 66 SUR 12
# {'Dirección ingresada': 'KR 17B BIS 66 SUR 12', 'Dirección encontrada': 'KR 17B BIS 66 12 S', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '111961', 'Sector catastral': 'LA ALAMEDA', 'UPZ': 'LUCERO (UPZ67)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.55206842400008', 'Longitud': '-74.1381875679999'}
# Rebuilt registers:  74 / 8000
# Registers not processed:  7 / 8000
# CL 57 SUR 87 06
# {'Dirección ingresada': 'CL 57 SUR 87 06', 'Dirección encontrada': 'CL 57 S 87 08', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '110711', 'Sector catastral': 'EL DANUBIO AZUL', 'UPZ': 'BOSA OCCIDENTAL (UPZ84)', 'Localidad': 'BOSA', 'Latitud': '4.62313560600006', 'Longitud': '-74.1850150529999'}
# Rebuilt registers:  75 / 8000
# Registers not processed:  7 / 8000
# KR 1F BIS ESTE 73 SUR 44
# Rebuilt registers:  75 / 8000
# Registers not processed:  8 / 8000
# CL 63 93 20
# {'Dirección ingresada': 'CL 63 93 20', 'Dirección encontrada': 'AC 63 93 50', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111071', 'Sector catastral': 'LOS ALAMOS', 'UPZ': 'ALAMOS (UPZ116)', 'Localidad': 'ENGATIVÁ', 'Latitud': '4.68947744900004', 'Longitud': '-74.1186213569999'}
# Rebuilt registers:  76 / 8000
# Registers not processed:  8 / 8000
# KR 80D 16 16
# {'Dirección ingresada': 'KR 80D 16 16', 'Dirección encontrada': 'KR 80D 16 14', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '110821', 'Sector catastral': 'EL VERGEL', 'UPZ': 'CASTILLA (UPZ46)', 'Localidad': 'KENNEDY', 'Latitud': '4.65418748400009', 'Longitud': '-74.1353972759999'}
# Rebuilt registers:  77 / 8000
# Registers not processed:  8 / 8000
# KR 51D 38A SUR 06
# {'Dirección ingresada': 'KR 51D 38A SUR 06', 'Dirección encontrada': 'KR 51D 38A 13 S', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111621', 'Sector catastral': 'OSPINA PEREZ', 'UPZ': 'MUZU (UPZ41)', 'Localidad': 'PUENTE ARANDA', 'Latitud': '4.59978074500009', 'Longitud': '-74.129600121'}
# Rebuilt registers:  78 / 8000
# Registers not processed:  8 / 8000
# DG 73 A BIS A SUR 82F 67
# {'Dirección ingresada': 'DG 73 A BIS A SUR 82F 67', 'Dirección encontrada': 'DG 73A BIS A S 82F 67', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '110731', 'Sector catastral': 'ISLANDIA', 'UPZ': 'BOSA CENTRAL (UPZ85)', 'Localidad': 'BOSA', 'Latitud': '4.61418161800009', 'Longitud': '-74.1974317159999'}
# Rebuilt registers:  79 / 8000
# Registers not processed:  8 / 8000
# CL 71F SUR 14B 36
# {'Dirección ingresada': 'CL 71F SUR 14B 36', 'Dirección encontrada': 'CL 71F S 14A 36', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '110511', 'Sector catastral': 'LA AURORA', 'UPZ': 'GRAN YOMASA (UPZ57)', 'Localidad': 'USME', 'Latitud': '4.52010836089436', 'Longitud': '-74.1187828931224'}
# Rebuilt registers:  80 / 8000
# Registers not processed:  8 / 8000
# CL 70A SUR 3B 75
# {'Dirección ingresada': 'CL 70A SUR 3B 75', 'Dirección encontrada': 'CL 70A S 3B 75', 'Tipo dirección': 'Dirección Antigua', 'Código postal': '110511', 'Sector catastral': 'LA AURORA', 'UPZ': 'GRAN YOMASA (UPZ57)', 'Localidad': 'USME', 'Latitud': '4.52356614897551', 'Longitud': '-74.1228646857542'}
# Rebuilt registers:  81 / 8000
# Registers not processed:  8 / 8000
# TV 42 24 SUR 25
# {'Dirección ingresada': 'TV 42 24 SUR 25', 'Dirección encontrada': 'KR 40B 24 S 25', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111631', 'Sector catastral': 'REMANSO SUR', 'UPZ': 'CIUDAD MONTES (UPZ40)', 'Localidad': 'PUENTE ARANDA', 'Latitud': '4.60179618558437', 'Longitud': '-74.1194662793754'}
# Rebuilt registers:  82 / 8000
# Registers not processed:  8 / 8000
# KR 14 45A SUR 25
# {'Dirección ingresada': 'KR 14 45A SUR 25', 'Dirección encontrada': 'AK 14 45A S 25', 'Tipo dirección': 'Dirección Antigua', 'Código postal': '111811', 'Sector catastral': 'SANTA LUCIA', 'UPZ': 'QUIROGA (UPZ39)', 'Localidad': 'RAFAEL URIBE URIBE', 'Latitud': '4.57265560942175', 'Longitud': '-74.1242290890729'}
# Rebuilt registers:  83 / 8000
# Registers not processed:  8 / 8000
# CL 143 8 47
# {'Dirección ingresada': 'CL 143 8 47', 'Dirección encontrada': 'CL 143 9 55', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '110121', 'Sector catastral': 'CEDRO NARVAEZ', 'UPZ': 'LOS CEDROS (UPZ13)', 'Localidad': 'USAQUÉN', 'Latitud': '4.72093438600007', 'Longitud': '-74.0333111659999'}
# Rebuilt registers:  84 / 8000
# Registers not processed:  8 / 8000
# CL 87A SUR 12 ESTE
# Rebuilt registers:  84 / 8000
# Registers not processed:  9 / 8000
# CL 39 SUR 52A 10
# {'Dirección ingresada': 'CL 39 SUR 52A 10', 'Dirección encontrada': 'CL 39 S 52A 10', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '111621', 'Sector catastral': 'ALQUERIA', 'UPZ': 'MUZU (UPZ41)', 'Localidad': 'PUENTE ARANDA', 'Latitud': '4.60067543400004', 'Longitud': '-74.131576273'}
# Rebuilt registers:  85 / 8000
# Registers not processed:  9 / 8000
# CL 48P SUR 1A 42
# {'Dirección ingresada': 'CL 48P SUR 1A 42', 'Dirección encontrada': 'CL 48P S 1A 42', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '111841', 'Sector catastral': 'CERROS DE ORIENTE', 'UPZ': 'DIANA TURBAY (UPZ55)', 'Localidad': 'RAFAEL URIBE URIBE', 'Latitud': '4.54746281000007', 'Longitud': '-74.1037179799999'}
# Rebuilt registers:  86 / 8000
# Registers not processed:  9 / 8000
# CL 71G BIS SUR 27A 16
# {'Dirección ingresada': 'CL 71G BIS SUR 27A 16', 'Dirección encontrada': 'CL 71G BIS S 27A 22', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111951', 'Sector catastral': 'EL MIRADOR', 'UPZ': 'LUCERO (UPZ67)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.55083307500007', 'Longitud': '-74.1591602809999'}
# Rebuilt registers:  87 / 8000
# Registers not processed:  9 / 8000
# KR 7 BIS 68 SUR 02
# {'Dirección ingresada': 'KR 7 BIS 68 SUR 02', 'Dirección encontrada': 'KR 7 BIS 68 02 S', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '110521', 'Sector catastral': 'DUITAMA', 'UPZ': 'DANUBIO (UPZ56)', 'Localidad': 'USME', 'Latitud': '4.52779999800009', 'Longitud': '-74.1137448269999'}
# Rebuilt registers:  88 / 8000
# Registers not processed:  9 / 8000
# KR 153 133 22
# {'Dirección ingresada': 'KR 153 133 22', 'Dirección encontrada': 'KR 153 133 22', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '111151', 'Sector catastral': 'LISBOA', 'UPZ': 'TIBABUYES (UPZ71)', 'Localidad': 'SUBA', 'Latitud': '4.74328505000005', 'Longitud': '-74.1237843829999'}
# Rebuilt registers:  89 / 8000
# Registers not processed:  9 / 8000
# KR 7B 138 78
# {'Dirección ingresada': 'KR 7B 138 78', 'Dirección encontrada': 'KR 7B 138 80', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '110121', 'Sector catastral': 'CEDRITOS', 'UPZ': 'LOS CEDROS (UPZ13)', 'Localidad': 'USAQUÉN', 'Latitud': '4.71651763500006', 'Longitud': '-74.0302962009999'}
# Rebuilt registers:  90 / 8000
# Registers not processed:  9 / 8000
# DG 65 SUR 86 14
# {'Dirección ingresada': 'DG 65 SUR 86 14', 'Dirección encontrada': 'DG 65 S 86 16', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '110721', 'Sector catastral': 'LOS SAUCES', 'UPZ': 'BOSA OCCIDENTAL (UPZ84)', 'Localidad': 'BOSA', 'Latitud': '4.61872582100006', 'Longitud': '-74.1910659729999'}
# Rebuilt registers:  91 / 8000
# Registers not processed:  9 / 8000
# DG 4B 8 ESTE 46
# Rebuilt registers:  91 / 8000
# Registers not processed:  10 / 8000
# CL 77 SUR 13 ESTE 25
# Rebuilt registers:  91 / 8000
# Registers not processed:  11 / 8000
# KR 48A 72 SUR 56
# {'Dirección ingresada': 'KR 48A 72 SUR 56', 'Dirección encontrada': 'KR 48A 72 48 S', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111931', 'Sector catastral': 'LA PRADERA', 'UPZ': 'JERUSALEM (UPZ70)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.57375382500004', 'Longitud': '-74.1627292829999'}
# Rebuilt registers:  92 / 8000
# Registers not processed:  11 / 8000
# KR 27F 62B SUR 28
# {'Dirección ingresada': 'KR 27F 62B SUR 28', 'Dirección encontrada': 'KR 27 62A S 28', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111941', 'Sector catastral': 'EL SATELITE', 'UPZ': 'SAN FRANCISCO (UPZ66)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.56946077975372', 'Longitud': '-74.1485152618524'}
# Rebuilt registers:  93 / 8000
# Registers not processed:  11 / 8000
# KR 113F 137
# {'Dirección ingresada': 'KR 113F 137', 'Dirección encontrada': 'KR 113 137A 0', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111141', 'Sector catastral': 'VILLA MARIA I', 'UPZ': 'EL RINCON (UPZ28)', 'Localidad': 'SUBA', 'Latitud': '4.74266809211997', 'Longitud': '-74.1044408101044'}
# Rebuilt registers:  94 / 8000
# Registers not processed:  11 / 8000
# KR 68L 37D SUR 68
# {'Dirección ingresada': 'KR 68L 37D SUR 68', 'Dirección encontrada': 'KR 68L 37D 69 S', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '110841', 'Sector catastral': 'PROVIVIENDA', 'UPZ': 'CARVAJAL (UPZ45)', 'Localidad': 'KENNEDY', 'Latitud': '4.60669885100009', 'Longitud': '-74.1393674649999'}
# Rebuilt registers:  95 / 8000
# Registers not processed:  11 / 8000
# KR 2D 30 SUR 15 15
# {'Dirección ingresada': 'KR 2D 30 SUR 15 15', 'Dirección encontrada': 'KR 2B 30A S 15', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '110421', 'Sector catastral': 'BELLO HORIZONTE', 'UPZ': '20 DE JULIO (UPZ34)', 'Localidad': 'SAN CRISTÓBAL', 'Latitud': '4.56510844771863', 'Longitud': '-74.0939051373823'}
# Rebuilt registers:  96 / 8000
# Registers not processed:  11 / 8000
# CL 133 148B 77
# {'Dirección ingresada': 'CL 133 148B 77', 'Dirección encontrada': 'CL 133 148B 79', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111151', 'Sector catastral': 'LISBOA', 'UPZ': 'TIBABUYES (UPZ71)', 'Localidad': 'SUBA', 'Latitud': '4.74451454400008', 'Longitud': '-74.1199851029999'}
# Rebuilt registers:  97 / 8000
# Registers not processed:  11 / 8000
# KR 40 19 SUR 84
# {'Dirección ingresada': 'KR 40 19 SUR 84', 'Dirección encontrada': 'KR 40A 19 S 84', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111631', 'Sector catastral': 'REMANSO SUR', 'UPZ': 'CIUDAD MONTES (UPZ40)', 'Localidad': 'PUENTE ARANDA', 'Latitud': '4.60195064211284', 'Longitud': '-74.1186381192791'}
# Rebuilt registers:  98 / 8000
# Registers not processed:  11 / 8000
# KR 80J 58J SUR 19
# {'Dirección ingresada': 'KR 80J 58J SUR 19', 'Dirección encontrada': 'KR 80J 58J 19 S', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '110731', 'Sector catastral': 'BOSA', 'UPZ': 'BOSA CENTRAL (UPZ85)', 'Localidad': 'BOSA', 'Latitud': '4.61263123200007', 'Longitud': '-74.1819143369999'}
# Rebuilt registers:  99 / 8000
# Registers not processed:  11 / 8000
# CL 77 B SUR 68
# {'Dirección ingresada': 'CL 77 B SUR 68', 'Dirección encontrada': 'CL 77B S 68 41', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111961', 'Sector catastral': 'NACIONES UNIDAS', 'UPZ': 'LUCERO (UPZ67)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.54012084600009', 'Longitud': '-74.149378028'}
# Rebuilt registers:  100 / 8000
# Registers not processed:  11 / 8000
# CL 34 BIS SUR 95 31
# {'Dirección ingresada': 'CL 34 BIS SUR 95 31', 'Dirección encontrada': 'CL 34 BIS S 95A 50', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '110871', 'Sector catastral': 'GALAN', 'UPZ': 'CALANDAIMA (UPZ79)', 'Localidad': 'KENNEDY', 'Latitud': '4.64939186900006', 'Longitud': '-74.1704849039999'}
# Rebuilt registers:  101 / 8000
# Registers not processed:  11 / 8000
# CL 120 104B 02
# {'Dirección ingresada': 'CL 120 104B 02', 'Dirección encontrada': 'CL 126 104 00', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111141', 'Sector catastral': 'LECH WALESA', 'UPZ': 'EL RINCON (UPZ28)', 'Localidad': 'SUBA', 'Latitud': '4.72625812900009', 'Longitud': '-74.1021492199999'}
# Rebuilt registers:  102 / 8000
# Registers not processed:  11 / 8000
# KR 12 BIA 49A SUR 27
# {'Dirección ingresada': 'KR 12 BIA 49A SUR 27', 'Dirección encontrada': 'KR 12A BIS 49A S 27', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111831', 'Sector catastral': 'ARBOLEDA SUR', 'UPZ': 'MARRUECOS (UPZ54)', 'Localidad': 'RAFAEL URIBE URIBE', 'Latitud': '4.56391085968363', 'Longitud': '-74.1192993701262'}
# Rebuilt registers:  103 / 8000
# Registers not processed:  11 / 8000
# CL 80A SUR 77 75
# {'Dirección ingresada': 'CL 80A SUR 77 75', 'Dirección encontrada': 'CL 80A S 77 41', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111931', 'Sector catastral': 'POTOSI', 'UPZ': 'JERUSALEM (UPZ70)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.56967181000005', 'Longitud': '-74.1704822899999'}
# Rebuilt registers:  104 / 8000
# Registers not processed:  11 / 8000
# CL 153C 136A 16
# {'Dirección ingresada': 'CL 153C 136A 16', 'Dirección encontrada': 'CL 153 136B 16', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111161', 'Sector catastral': 'SABANA DE TIBABUYES NORTE', 'UPZ': 'TIBABUYES (UPZ71)', 'Localidad': 'SUBA', 'Latitud': '4.76027165341605', 'Longitud': '-74.1053226748129'}
# Rebuilt registers:  105 / 8000
# Registers not processed:  11 / 8000
# CL 16 5 260
# {'Dirección ingresada': 'CL 16 5 260', 'Dirección encontrada': 'CL 16 5 70', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '110321', 'Sector catastral': 'VERACRUZ', 'UPZ': 'LAS NIEVES (UPZ93)', 'Localidad': 'SANTA FE', 'Latitud': '4.60212256900007', 'Longitud': '-74.0719587089999'}
# Rebuilt registers:  106 / 8000
# Registers not processed:  11 / 8000
# CL 78A SUR 0 ESTE 24
# Rebuilt registers:  106 / 8000
# Registers not processed:  12 / 8000
# KR 4 13A 12
# {'Dirección ingresada': 'KR 4 13A 12', 'Dirección encontrada': 'KR 4 13 12', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111711', 'Sector catastral': 'LA CATEDRAL', 'UPZ': 'LAS NIEVES (UPZ93)', 'Localidad': 'SANTA FE', 'Latitud': '4.60081486906141', 'Longitud': '-74.0700142571107'}
# Rebuilt registers:  107 / 8000
# Registers not processed:  12 / 8000
# CL 65H SUR 78G 33
# {'Dirección ingresada': 'CL 65H SUR 78G 33', 'Dirección encontrada': 'CL 65H S 78G 33', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '110741', 'Sector catastral': 'SAN PABLO BOSA', 'UPZ': 'BOSA CENTRAL (UPZ85)', 'Localidad': 'BOSA', 'Latitud': '4.60288936100005', 'Longitud': '-74.1863618869999'}
# Rebuilt registers:  108 / 8000
# Registers not processed:  12 / 8000
# DG 74B SUR 2 ESTE 36
# Rebuilt registers:  108 / 8000
# Registers not processed:  13 / 8000
# DG 60A SUR 75 32
# {'Dirección ingresada': 'DG 60A SUR 75 32', 'Dirección encontrada': 'CL 60A S 75 22', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111921', 'Sector catastral': 'LA ESTANCIA', 'UPZ': 'ISMAEL PERDOMO (UPZ69)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.59193976900008', 'Longitud': '-74.1755845469999'}
# Rebuilt registers:  109 / 8000
# Registers not processed:  13 / 8000
# TV 5B BIS 53 SUR 48
# {'Dirección ingresada': 'TV 5B BIS 53 SUR 48', 'Dirección encontrada': 'TV 5B BIS 53 S 48', 'Tipo dirección': 'Dirección Antigua', 'Código postal': '111841', 'Sector catastral': 'LA PICOTA ORIENTAL', 'UPZ': 'DIANA TURBAY (UPZ55)', 'Localidad': 'RAFAEL URIBE URIBE', 'Latitud': '4.54511983578393', 'Longitud': '-74.1164621026268'}
# Rebuilt registers:  110 / 8000
# Registers not processed:  13 / 8000
# KR 3 183 55
# {'Dirección ingresada': 'KR 3 183 55', 'Dirección encontrada': 'KR 3 183A 55', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '110141', 'Sector catastral': 'HORIZONTES NORTE', 'UPZ': 'VERBENAL (UPZ9)', 'Localidad': 'USAQUÉN', 'Latitud': '4.76116561096215', 'Longitud': '-74.0234241006842'}
# Rebuilt registers:  111 / 8000
# Registers not processed:  13 / 8000
# KR 13A ESTE 10
# Rebuilt registers:  111 / 8000
# Registers not processed:  14 / 8000
# KR 12 32A SUR 86
# {'Dirección ingresada': 'KR 12 32A SUR 86', 'Dirección encontrada': 'KR 12 32A 38 S', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111821', 'Sector catastral': 'LA RESURRECCION', 'UPZ': 'MARCO FIDEL SUAREZ (UPZ53)', 'Localidad': 'RAFAEL URIBE URIBE', 'Latitud': '4.56789954000004', 'Longitud': '-74.1106640279999'}
# Rebuilt registers:  112 / 8000
# Registers not processed:  14 / 8000
# CL 75B 78 77
# {'Dirección ingresada': 'CL 75B 78 77', 'Dirección encontrada': 'CL 75B 78 78', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111051', 'Sector catastral': 'TABORA', 'UPZ': 'BOYACA REAL (UPZ30)', 'Localidad': 'ENGATIVÁ', 'Latitud': '4.69648724500007', 'Longitud': '-74.0985874469999'}
# Rebuilt registers:  113 / 8000
# Registers not processed:  14 / 8000
# KR 7 162 13
# {'Dirección ingresada': 'KR 7 162 13', 'Dirección encontrada': 'AK 7 162 13', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '110131', 'Sector catastral': 'SAN CRISTOBAL NORTE', 'UPZ': 'SAN CRISTOBAL NORTE (UPZ11)', 'Localidad': 'USAQUÉN', 'Latitud': '4.73712650700008', 'Longitud': '-74.023402556'}
# Rebuilt registers:  114 / 8000
# Registers not processed:  14 / 8000
# CL 97C SUR 0 48
# {'Dirección ingresada': 'CL 97C SUR 0 48', 'Dirección encontrada': 'CL 97C S 0 E 48', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '110531', 'Sector catastral': 'LA ORQUIDEA DE USME', 'UPZ': 'ALFONSO LOPEZ (UPZ59)', 'Localidad': 'USME', 'Latitud': '4.49563775119799', 'Longitud': '-74.1069427864408'}
# Rebuilt registers:  115 / 8000
# Registers not processed:  14 / 8000
# CL 144 111 NO DA MAS
# {'Dirección ingresada': 'CL 144 111 NO DA MAS', 'Dirección encontrada': 'CL 144 111B 04', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111141', 'Sector catastral': 'LOMBARDIA', 'UPZ': 'EL RINCON (UPZ28)', 'Localidad': 'SUBA', 'Latitud': '4.74883585000009', 'Longitud': '-74.101016592'}
# Rebuilt registers:  116 / 8000
# Registers not processed:  14 / 8000
# KR 113 113A 04
# {'Dirección ingresada': 'KR 113 113A 04', 'Dirección encontrada': 'KR 113 113 01', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '110921', 'Sector catastral': 'BELEN FONTIBON', 'UPZ': 'FONTIBON (UPZ75)', 'Localidad': 'FONTIBÓN', 'Latitud': '4.68251484400008', 'Longitud': '-74.1517014089999'}
# Rebuilt registers:  117 / 8000
# Registers not processed:  14 / 8000
# CL 5A 88H 16
# {'Dirección ingresada': 'CL 5A 88H 16', 'Dirección encontrada': 'CL 5A 88H 10', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '110871', 'Sector catastral': 'PATIO BONITO III', 'UPZ': 'PATIO BONITO (UPZ82)', 'Localidad': 'KENNEDY', 'Latitud': '4.64454411400004', 'Longitud': '-74.1609370259999'}
# Rebuilt registers:  118 / 8000
# Registers not processed:  14 / 8000
# KR 18D 5A
# ...
# Rebuilt registers:  6847 / 8000
# Registers not processed:  1084 / 8000
# KR 120B 73 14
# {'Dirección ingresada': 'KR 120B 73 14', 'Dirección encontrada': 'KR 120B 73 02', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111031', 'Sector catastral': 'VILLAS DE ALCALA', 'UPZ': 'GARCES NAVAS (UPZ73)', 'Localidad': 'ENGATIVÁ', 'Latitud': '4.71858318200009', 'Longitud': '-74.1325936219999'}
# Rebuilt registers:  6848 / 8000
# Registers not processed:  1084 / 8000
# KR 84D 67 SUR 15
# {'Dirección ingresada': 'KR 84D 67 SUR 15', 'Dirección encontrada': 'KR 84C 67 S 15', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '110721', 'Sector catastral': 'LOS SAUCES', 'UPZ': 'BOSA OCCIDENTAL (UPZ84)', 'Localidad': 'BOSA', 'Latitud': '4.61681150648379', 'Longitud': '-74.1910804434523'}
# Rebuilt registers:  6849 / 8000
# Registers not processed:  1084 / 8000
# CL 64 116C 17
# {'Dirección ingresada': 'CL 64 116C 17', 'Dirección encontrada': 'CL 64 116C 13', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111031', 'Sector catastral': 'SABANA DEL DORADO', 'UPZ': 'ENGATIVA (UPZ74)', 'Localidad': 'ENGATIVÁ', 'Latitud': '4.71120986900007', 'Longitud': '-74.1401860559999'}
# Rebuilt registers:  6850 / 8000
# Registers not processed:  1084 / 8000
# DG 77 SUR 28 21
# {'Dirección ingresada': 'DG 77 SUR 28 21', 'Dirección encontrada': 'CL 77 S 28 41', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111941', 'Sector catastral': 'ARBORIZADORA ALTA', 'UPZ': 'JERUSALEM (UPZ70)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.56536268600007', 'Longitud': '-74.1679505069999'}
# Rebuilt registers:  6851 / 8000
# Registers not processed:  1084 / 8000
# KR 30A 12 SUR
# {'Dirección ingresada': 'KR 30A 12 SUR', 'Dirección encontrada': 'KR 30 12 S 0', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111511', 'Sector catastral': 'LA FRAGUA', 'UPZ': 'RESTREPO (UPZ38)', 'Localidad': 'ANTONIO NARIÑO', 'Latitud': '4.59774997861649', 'Longitud': '-74.10752976971'}
# Rebuilt registers:  6852 / 8000
# Registers not processed:  1084 / 8000
# KR 8 ESTE 24 SUR 39
# Rebuilt registers:  6852 / 8000
# Registers not processed:  1085 / 8000
# CL 129B 104D 34
# {'Dirección ingresada': 'CL 129B 104D 34', 'Dirección encontrada': 'CL 129C 104D 34', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111141', 'Sector catastral': 'AURES II', 'UPZ': 'EL RINCON (UPZ28)', 'Localidad': 'SUBA', 'Latitud': '4.73127345613957', 'Longitud': '-74.1018756694851'}
# Rebuilt registers:  6853 / 8000
# Registers not processed:  1085 / 8000
# KR 12H 31A SUR 55
# {'Dirección ingresada': 'KR 12H 31A SUR 55', 'Dirección encontrada': 'KR 12H 31A 55 S', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '111821', 'Sector catastral': 'GUSTAVO RESTREPO', 'UPZ': 'SAN JOSE (UPZ36)', 'Localidad': 'RAFAEL URIBE URIBE', 'Latitud': '4.57391537500007', 'Longitud': '-74.1079118739999'}
# Rebuilt registers:  6854 / 8000
# Registers not processed:  1085 / 8000
# KR 111C 60G
# {'Dirección ingresada': 'KR 111C 60G', 'Dirección encontrada': 'KR 110F 60 0', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111031', 'Sector catastral': 'SAN ANTONIO URBANO', 'UPZ': 'ENGATIVA (UPZ74)', 'Localidad': 'ENGATIVÁ', 'Latitud': '4.70108370559353', 'Longitud': '-74.1326969722579'}
# Rebuilt registers:  6855 / 8000
# Registers not processed:  1085 / 8000
# CL 48W SUR 5J 71
# {'Dirección ingresada': 'CL 48W SUR 5J 71', 'Dirección encontrada': 'CL 48W S 5J 71', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '111831', 'Sector catastral': 'MARRUECOS', 'UPZ': 'MARRUECOS (UPZ54)', 'Localidad': 'RAFAEL URIBE URIBE', 'Latitud': '4.55344552300005', 'Longitud': '-74.1136257659999'}
# Rebuilt registers:  6856 / 8000
# Registers not processed:  1085 / 8000
# KR 153B 138 46
# {'Dirección ingresada': 'KR 153B 138 46', 'Dirección encontrada': 'KR 153 138 16', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111151', 'Sector catastral': 'SANTA RITA DE SUBA', 'UPZ': 'TIBABUYES (UPZ71)', 'Localidad': 'SUBA', 'Latitud': '4.74532399800006', 'Longitud': '-74.1247104189999'}
# Rebuilt registers:  6857 / 8000
# Registers not processed:  1085 / 8000
# KR 103A 159 43
# {'Dirección ingresada': 'KR 103A 159 43', 'Dirección encontrada': 'KR 103A 159 43', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '111161', 'Sector catastral': 'LAS MERCEDES I', 'UPZ': 'SUBA (UPZ27)', 'Localidad': 'SUBA', 'Latitud': '4.75826320900006', 'Longitud': '-74.0896547059999'}
# Rebuilt registers:  6858 / 8000
# Registers not processed:  1085 / 8000
# CL 66 SUR 21A
# {'Dirección ingresada': 'CL 66 SUR 21A', 'Dirección encontrada': 'CL 66 S 21A 02', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111941', 'Sector catastral': 'SAN FRANCISCO', 'UPZ': 'SAN FRANCISCO (UPZ66)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.56508400500007', 'Longitud': '-74.148393859'}
# Rebuilt registers:  6859 / 8000
# Registers not processed:  1085 / 8000
# CL 36 SUR 26D 52
# {'Dirección ingresada': 'CL 36 SUR 26D 52', 'Dirección encontrada': 'CL 36 S 26D 52', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '111811', 'Sector catastral': 'BRAVO PAEZ', 'UPZ': 'QUIROGA (UPZ39)', 'Localidad': 'RAFAEL URIBE URIBE', 'Latitud': '4.58653929400009', 'Longitud': '-74.1218015789999'}
# Rebuilt registers:  6860 / 8000
# Registers not processed:  1085 / 8000
# KR 131 132 53
# {'Dirección ingresada': 'KR 131 132 53', 'Dirección encontrada': 'KR 131 132 55', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111151', 'Sector catastral': 'TOSCANA', 'UPZ': 'TIBABUYES (UPZ71)', 'Localidad': 'SUBA', 'Latitud': '4.74146588500008', 'Longitud': '-74.1145661049999'}
# Rebuilt registers:  6861 / 8000
# Registers not processed:  1085 / 8000
# CL 58 SUR 45A
# {'Dirección ingresada': 'CL 58 SUR 45A', 'Dirección encontrada': 'CL 58 S 45 41', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111911', 'Sector catastral': 'ARBORIZADORA BAJA', 'UPZ': 'ARBORIZADORA (UPZ65)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.57483804600008', 'Longitud': '-74.1487600429999'}
# Rebuilt registers:  6862 / 8000
# Registers not processed:  1085 / 8000
# CL 60 SUR 78B 58
# {'Dirección ingresada': 'CL 60 SUR 78B 58', 'Dirección encontrada': 'CL 60 S 78B 42', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '110741', 'Sector catastral': 'ANDALUCIA II', 'UPZ': 'BOSA CENTRAL (UPZ85)', 'Localidad': 'BOSA', 'Latitud': '4.60292400900005', 'Longitud': '-74.1801925699999'}
# Rebuilt registers:  6863 / 8000
# Registers not processed:  1085 / 8000
# CL 70G 113 81
# {'Dirección ingresada': 'CL 70G 113 81', 'Dirección encontrada': 'CL 70G 113 83', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111031', 'Sector catastral': 'LA RIVIERA', 'UPZ': 'ENGATIVA (UPZ74)', 'Localidad': 'ENGATIVÁ', 'Latitud': '4.71188499700008', 'Longitud': '-74.1313377709999'}
# Rebuilt registers:  6864 / 8000
# Registers not processed:  1085 / 8000
# CL 28 SUR 61F
# {'Dirección ingresada': 'CL 28 SUR 61F', 'Dirección encontrada': 'CL 24A S 63 12', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111621', 'Sector catastral': 'PROVIVIENDA NORTE', 'UPZ': 'SAN RAFAEL (UPZ43)', 'Localidad': 'PUENTE ARANDA', 'Latitud': '4.61031345600009', 'Longitud': '-74.1282243079999'}
# Rebuilt registers:  6865 / 8000
# Registers not processed:  1085 / 8000
# CL 129B BIS 94
# {'Dirección ingresada': 'CL 129B BIS 94', 'Dirección encontrada': 'CL 129B 94A 04', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111131', 'Sector catastral': 'EL RINCON NORTE', 'UPZ': 'EL RINCON (UPZ28)', 'Localidad': 'SUBA', 'Latitud': '4.72578836600007', 'Longitud': '-74.0929445269999'}
# Rebuilt registers:  6866 / 8000
# Registers not processed:  1085 / 8000
# CL 1D 5A 37
# {'Dirección ingresada': 'CL 1D 5A 37', 'Dirección encontrada': 'CL 1D 5A 37', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '110321', 'Sector catastral': 'LAS CRUCES', 'UPZ': 'LAS CRUCES (UPZ95)', 'Localidad': 'SANTA FE', 'Latitud': '4.58719568300006', 'Longitud': '-74.0795479129999'}
# Rebuilt registers:  6867 / 8000
# Registers not processed:  1085 / 8000
# TV 3 ESTE 24 SUR 22
# Rebuilt registers:  6867 / 8000
# Registers not processed:  1086 / 8000
# KR 12J 32 SUR 11
# {'Dirección ingresada': 'KR 12J 32 SUR 11', 'Dirección encontrada': 'KR 12J 32 10 S', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111821', 'Sector catastral': 'HOSPITAL SAN CARLOS', 'UPZ': 'SAN JOSE (UPZ36)', 'Localidad': 'RAFAEL URIBE URIBE', 'Latitud': '4.57337452800004', 'Longitud': '-74.1092548319999'}
# Rebuilt registers:  6868 / 8000
# Registers not processed:  1086 / 8000
# KR 88H 40 SUR 35
# {'Dirección ingresada': 'KR 88H 40 SUR 35', 'Dirección encontrada': 'KR 88H 40 33 S', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '110881', 'Sector catastral': 'PROVIVIENDA OCCIDENTAL', 'UPZ': 'PATIO BONITO (UPZ82)', 'Localidad': 'KENNEDY', 'Latitud': '4.63810416200005', 'Longitud': '-74.1688593719999'}
# Rebuilt registers:  6869 / 8000
# Registers not processed:  1086 / 8000
# CL 132 94 617
# {'Dirección ingresada': 'CL 132 94 617', 'Dirección encontrada': 'AC 132 94 28', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111131', 'Sector catastral': 'VILLA ELISA', 'UPZ': 'EL RINCON (UPZ28)', 'Localidad': 'SUBA', 'Latitud': '4.73188859600009', 'Longitud': '-74.0894002969999'}
# Rebuilt registers:  6870 / 8000
# Registers not processed:  1086 / 8000
# CL 132B 123D
# {'Dirección ingresada': 'CL 132B 123D', 'Dirección encontrada': 'CL 132B 123B 01', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111141', 'Sector catastral': 'LA GAITANA ORIENTAL', 'UPZ': 'TIBABUYES (UPZ71)', 'Localidad': 'SUBA', 'Latitud': '4.73912853800005', 'Longitud': '-74.1065100629999'}
# Rebuilt registers:  6871 / 8000
# Registers not processed:  1086 / 8000
# CL 65 96 50
# {'Dirección ingresada': 'CL 65 96 50', 'Dirección encontrada': 'CL 65 96 50', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '111041', 'Sector catastral': 'LOS ANGELES', 'UPZ': 'ALAMOS (UPZ116)', 'Localidad': 'ENGATIVÁ', 'Latitud': '4.69349641400004', 'Longitud': '-74.1200407359999'}
# Rebuilt registers:  6872 / 8000
# Registers not processed:  1086 / 8000
# KR 2H 37D SUR 15
# {'Dirección ingresada': 'KR 2H 37D SUR 15', 'Dirección encontrada': 'KR 2H 37D 15 S', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '110431', 'Sector catastral': 'LAS GUACAMAYAS III', 'UPZ': 'LA GLORIA (UPZ50)', 'Localidad': 'SAN CRISTÓBAL', 'Latitud': '4.55712407700008', 'Longitud': '-74.0992214149999'}
# Rebuilt registers:  6873 / 8000
# Registers not processed:  1086 / 8000
# CL 35 BIS SUR 8 38
# {'Dirección ingresada': 'CL 35 BIS SUR 8 38', 'Dirección encontrada': 'CL 35 BIS S 8 40', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '110431', 'Sector catastral': 'LAS LOMAS', 'UPZ': '20 DE JULIO (UPZ34)', 'Localidad': 'SAN CRISTÓBAL', 'Latitud': '4.56528820200009', 'Longitud': '-74.1022787729999'}
# Rebuilt registers:  6874 / 8000
# Registers not processed:  1086 / 8000
# KR 75C 75D SUR 25
# {'Dirección ingresada': 'KR 75C 75D SUR 25', 'Dirección encontrada': 'KR 75C 75D 25 S', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '111931', 'Sector catastral': 'SANTA VIVIANA', 'UPZ': 'ISMAEL PERDOMO (UPZ69)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.57609238900005', 'Longitud': '-74.1751563279999'}
# Rebuilt registers:  6875 / 8000
# Registers not processed:  1086 / 8000
# KR 77G 78 SUR 33
# {'Dirección ingresada': 'KR 77G 78 SUR 33', 'Dirección encontrada': 'KR 77G 78 33 S', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '110731', 'Sector catastral': 'SAN DIEGO-BOSA', 'UPZ': 'BOSA CENTRAL (UPZ85)', 'Localidad': 'BOSA', 'Latitud': '4.60712109100007', 'Longitud': '-74.209482653'}
# Rebuilt registers:  6876 / 8000
# Registers not processed:  1086 / 8000
# CL 6B 2 29 29
# {'Dirección ingresada': 'CL 6B 2 29 29', 'Dirección encontrada': 'CL 6B 2 29', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '111711', 'Sector catastral': 'LOURDES', 'UPZ': 'LA CANDELARIA (UPZ94)', 'Localidad': 'CANDELARIA', 'Latitud': '4.59039331400004', 'Longitud': '-74.0739098459999'}
# Rebuilt registers:  6877 / 8000
# Registers not processed:  1086 / 8000
# KR 72J 37D SUR 33
# {'Dirección ingresada': 'KR 72J 37D SUR 33', 'Dirección encontrada': 'KR 72J 37D 41 S', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '110841', 'Sector catastral': 'PROVIVIENDA OCCIDENTAL', 'UPZ': 'CARVAJAL (UPZ45)', 'Localidad': 'KENNEDY', 'Latitud': '4.61250567900004', 'Longitud': '-74.1427478369999'}
# Rebuilt registers:  6878 / 8000
# Registers not processed:  1086 / 8000
# KR 18A 1 41
# {'Dirección ingresada': 'KR 18A 1 41', 'Dirección encontrada': 'KR 18A 1 41', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '111961', 'Sector catastral': 'ESTRELLA DEL SUR', 'UPZ': 'LUCERO (UPZ67)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.54732721000005', 'Longitud': '-74.1441354219999'}
# Rebuilt registers:  6879 / 8000
# Registers not processed:  1086 / 8000
# KR 14 24 76
# {'Dirección ingresada': 'KR 14 24 76', 'Dirección encontrada': 'AK 14 24 19', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111411', 'Sector catastral': 'SANTA FE', 'UPZ': 'LA SABANA (UPZ102)', 'Localidad': 'LOS MÁRTIRES', 'Latitud': '4.61298815100008', 'Longitud': '-74.074247839'}
# Rebuilt registers:  6880 / 8000
# Registers not processed:  1086 / 8000
# CL 2 SUR 87F 52
# {'Dirección ingresada': 'CL 2 SUR 87F 52', 'Dirección encontrada': 'CL 3 S 87 41', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '110831', 'Sector catastral': 'HIPOTECHO OCCIDENTAL', 'UPZ': 'AMERICAS (UPZ44)', 'Localidad': 'KENNEDY', 'Latitud': '4.62032515800007', 'Longitud': '-74.1314973769999'}
# Rebuilt registers:  6881 / 8000
# Registers not processed:  1086 / 8000
# KR 29 62 SUR 11
# {'Dirección ingresada': 'KR 29 62 SUR 11', 'Dirección encontrada': 'KR 29 62 12 S', 'Tipo dirección': 'Aproximación por placa', 'Código postal': '111941', 'Sector catastral': 'EL SATELITE', 'UPZ': 'SAN FRANCISCO (UPZ66)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.56988682300005', 'Longitud': '-74.1488792909999'}
# Rebuilt registers:  6882 / 8000
# Registers not processed:  1086 / 8000
# CL 69M 18M SUR
# {'Dirección ingresada': 'CL 69M 18M SUR', 'Dirección encontrada': 'CL 69I BIS 18N 28', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '111951', 'Sector catastral': 'VILLAS EL DIAMANTE', 'UPZ': 'LUCERO (UPZ67)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.55381653100005', 'Longitud': '-74.1534238129999'}
# Rebuilt registers:  6883 / 8000
# Registers not processed:  1086 / 8000
# KR 76 142 80
# {'Dirección ingresada': 'KR 76 142 80', 'Dirección encontrada': 'KR 78K 142 41', 'Tipo dirección': 'Aproximación por malla', 'Código postal': '110741', 'Sector catastral': 'VILLA ANNY I', 'UPZ': 'BOSA CENTRAL (UPZ85)', 'Localidad': 'BOSA', 'Latitud': '4.60555476500008', 'Longitud': '-74.2031487389999'}
# Rebuilt registers:  6884 / 8000
# Registers not processed:  1086 / 8000
# CL 8B 82A 22
# {'Dirección ingresada': 'CL 8B 82A 22', 'Dirección encontrada': 'CL 8B 82A 22', 'Tipo dirección': 'Asignada por Catastro', 'Código postal': '110821', 'Sector catastral': 'VALLADOLID', 'UPZ': 'CASTILLA (UPZ46)', 'Localidad': 'KENNEDY', 'Latitud': '4.64611507200004', 'Longitud': '-74.1481386109999'}
# Rebuilt registers:  6885 / 8000
# Registers not processed:  1086 / 8000
# DG 100F SUR 4B ESTE 30
# Rebuilt registers:  6885 / 8000
# Registers not processed:  1087 / 8000
# KR 64A 62D SUR 53
# {'Dirección ingresada': 'KR 64A 62D SUR 53', 'Dirección encontrada': 'CL 62D S 64A 53', 'Tipo dirección': 'Dirección Antigua', 'Código postal': '110611', 'Sector catastral': 'ISLA DEL SOL', 'UPZ': 'ARBORIZADORA (UPZ65)', 'Localidad': 'CIUDAD BOLÍVAR', 'Latitud': '4.59064470736591', 'Longitud': '-74.1550893705658'}
# Rebuilt registers:  6886 / 8000
# Registers not processed:  1087 / 8000

# %%
print(rebuilt_registers)
print(registers_not_processed)
print(other_condition_counter)
# Out:
# 6886
# 1087
# 0

# %%
#save lists
MyFile=open('/home/combios/Documents/amreyesp/idx_error_loading_address_29012020.txt','w')
MyList=map(lambda x: str(x)+', ', idx_error_loading_address)
MyFile.writelines(MyList)
MyFile.close()

# %%
df_output.to_csv(r'/home/combios/Documents/amreyesp/rebuild_locations_nuse_idx_39kto48k_29012020.csv',index=None)

# %%
#iterate over idx_error_loading_address to rebuild location if necesary
